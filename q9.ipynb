# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import truncnorm
import time
import csv


def get_s_cond_t_params(player_1_sigma, player_2_sigma, player_1_mean, player_2_mean, t_i):
    beta = 3  # från uppgiften

    # Covariance calculations
    covariance_t_given_s = beta
    covariance_ss = np.array([[player_1_sigma, 0], [0, player_2_sigma]])
    A = np.array([1, -1]).reshape([1, 2])
    inv_covariance_ss = np.linalg.inv(covariance_ss)
    ACA = np.matmul(A.T, A) * (1 / covariance_t_given_s)
    covariance_s_cond_t = np.linalg.inv(inv_covariance_ss + ACA)

    # Mean calculations
    player_means = np.array([player_1_mean, player_2_mean]).reshape([2, 1])
    a = covariance_s_cond_t
    b = np.matmul(inv_covariance_ss, player_means)
    c = A.T * (1 / covariance_t_given_s) * t_i
    mean_s_cond_t = np.matmul(a, b + c)

    return mean_s_cond_t, covariance_s_cond_t


def P_s_cond_t(t_i, player_1_mean, player_1_sigma, player_2_mean, player_2_sigma):
    # player_1_mean = 25; player_2_mean = 25; player_1_sigma = 8.3**2; player_2_sigma = 8.3**2

    mean_s_cond_t, cov_s_cond_t = get_s_cond_t_params(player_1_mean=player_1_mean, player_1_sigma=player_1_sigma,
                                                      player_2_mean=player_2_mean, player_2_sigma=player_2_sigma,
                                                      t_i=t_i)

    return np.random.multivariate_normal(mean=mean_s_cond_t.reshape(2), cov=cov_s_cond_t,
                                         check_valid='warn', tol=1e-8)


def P_t_cond_s(s_i, t_game):
    s_diff = s_i[0] - s_i[1]
    beta = 3
    t_sigma = beta

    if t_game > 0:  # case for when y=1
        a, b = (0 - s_diff) / t_sigma, np.inf
        t = truncnorm.rvs(a, b) * t_sigma + s_diff
        return t
    elif t_game < 0:  # case for when y=-1
        a, b = -np.inf, (0 - s_diff) / t_sigma
        t = truncnorm.rvs(a, b) * t_sigma + s_diff
        return t
    else:
        print("ERROR, TIES PRESENTLY NOT ALLOWED")


        
def gibbs_sampler(L, player_1_stats, player_2_stats, t_game):
    player_1_mean, player_1_sigma = player_1_stats
    player_2_mean, player_2_sigma = player_2_stats
    
    s_i = [player_1_mean, player_2_mean]

    t_obs = np.zeros(L)
    s_obs = np.zeros([L, 2])

    for i in range(L):
        t_i_plus_1 = P_t_cond_s(s_i, t_game=t_game)
        s_i_plus_1 = P_s_cond_t(t_i_plus_1, player_1_mean, player_1_sigma, player_2_mean, player_2_sigma)

        t_obs[i] = t_i_plus_1
        s_obs[i, :] = s_i_plus_1

        s_i = s_i_plus_1
        # plt.scatter(s_obs[:, 0], s_obs[:, 1])
        # plt.pause(0.1)
    # plt.show()

    # plt.plot(s_obs[:, 0]); plt.plot(s_obs[:, 1]); plt.show()
    return s_obs, t_obs



def player_stats_estimate_from_obs(s_obs):
    player_1_stats_estimate = [np.mean(s_obs[:, 0]), np.var(s_obs[:, 0])] # [mean, variance] of samples
    player_2_stats_estimate = [np.mean(s_obs[:, 1]), np.var(s_obs[:, 1])] # [mean, variance] of samples
    
    return player_1_stats_estimate, player_2_stats_estimate


    

def make_stats_dictionary(filename, stats_dictionary, printable):
    with open(filename) as csvfile:
        reader = csv.DictReader(csvfile)
        mean = 100; variance = (100 / 3) ** 2  # TrueSkill prior parameters before any games
        gamelist = []
        for row in reader:
            # Create dictionary (=map) with keyword 'team' and value [mean, variance]
            stats_dictionary[row['team1']] = [mean, variance]
            # Add teams and result to list
            gamelist.append([row['team1'], row['team2'], int(row['result'])])

            if printable == 1:  # Print the whole list
                print(f"{row['team1']} vs {row['team2']}: {row['result']}")  # Access by column header
                      
    #stats_dictionary = random.shuffle(stats_dictionary, random)

    return stats_dictionary, gamelist



# Ranking by mean (should perhaps be improved to mean - 3 * sigma)
def ranking(stats_dictionary):
    sorted_teams = sorted(stats_dictionary.items(), key=lambda x: x[1], reverse=True)
    print("\nList of teams ranked by mean skill in descending order:\n")
    for i in sorted_teams:
        print(i[0], i[1])

        
def predict_winner(team1_string, team2_string, stats_dictionary):
    diff = stats_dictionary[team1_string][0] - stats_dictionary[team2_string][0] 
    #print('statdic team1 : ', stats_dictionary[team1_string][0])
    #print('statdic team2 : ', stats_dictionary[team2_string][0])
    print('\t diff: ', diff)
    
    if diff > 0:
        return 1
    elif diff < 0:
        return -1
    else:
        return 1

# %%
# Make dictionary of team stats (mean and variance) & list of all games with result
stats_dictionary, result_list = make_stats_dictionary('syntheticSerieA.csv', stats_dictionary={}, printable=0)
stats_dictionary
# Out:
# {'Chievo': [100, 1111.1111111111113],
#  'Lazio': [100, 1111.1111111111113],
#  'Torino': [100, 1111.1111111111113],
#  'Sassuolo': [100, 1111.1111111111113],
#  'Parma': [100, 1111.1111111111113],
#  'Empoli': [100, 1111.1111111111113],
#  'Bologna': [100, 1111.1111111111113],
#  'Atalanta': [100, 1111.1111111111113],
#  'Juventus': [100, 1111.1111111111113],
#  'Napoli': [100, 1111.1111111111113],
#  'Spal': [100, 1111.1111111111113],
#  'Udinese': [100, 1111.1111111111113],
#  'Inter': [100, 1111.1111111111113],
#  'Genoa': [100, 1111.1111111111113],
#  'Frosinone': [100, 1111.1111111111113],
#  'Fiorentina': [100, 1111.1111111111113],
#  'Cagliari': [100, 1111.1111111111113],
#  'Roma': [100, 1111.1111111111113],
#  'Milan': [100, 1111.1111111111113],
#  'Sampdoria': [100, 1111.1111111111113]}

# %%
result_list
# Out:
# [['Chievo', 'Lazio', 1],
#  ['Chievo', 'Torino', 1],
#  ['Chievo', 'Sassuolo', 1],
#  ['Chievo', 'Parma', 1],
#  ['Chievo', 'Empoli', 1],
#  ['Chievo', 'Bologna', -1],
#  ['Chievo', 'Atalanta', -1],
#  ['Chievo', 'Juventus', 1],
#  ['Chievo', 'Napoli', 1],
#  ['Chievo', 'Spal', 1],
#  ['Chievo', 'Udinese', 1],
#  ['Chievo', 'Inter', 1],
#  ['Chievo', 'Genoa', 1],
#  ['Chievo', 'Frosinone', 1],
#  ['Chievo', 'Fiorentina', 1],
#  ['Chievo', 'Cagliari', -1],
#  ['Chievo', 'Roma', 1],
#  ['Chievo', 'Milan', 1],
#  ['Chievo', 'Sampdoria', 1],
#  ['Lazio', 'Torino', 1],
#  ['Lazio', 'Sassuolo', 1],
#  ['Lazio', 'Parma', 1],
#  ['Lazio', 'Empoli', -1],
#  ['Lazio', 'Bologna', -1],
#  ['Lazio', 'Atalanta', -1],
#  ['Lazio', 'Juventus', -1],
#  ['Lazio', 'Napoli', 1],
#  ['Lazio', 'Spal', 1],
#  ['Lazio', 'Udinese', 1],
#  ['Lazio', 'Inter', -1],
#  ['Lazio', 'Genoa', -1],
#  ['Lazio', 'Frosinone', -1],
#  ['Lazio', 'Fiorentina', -1],
#  ['Lazio', 'Cagliari', -1],
#  ['Lazio', 'Roma', 1],
#  ['Lazio', 'Milan', 1],
#  ['Lazio', 'Sampdoria', 1],
#  ['Torino', 'Sassuolo', -1],
#  ['Torino', 'Parma', -1],
#  ['Torino', 'Empoli', -1],
#  ['Torino', 'Bologna', -1],
#  ['Torino', 'Atalanta', -1],
#  ['Torino', 'Juventus', -1],
#  ['Torino', 'Napoli', -1],
#  ['Torino', 'Spal', -1],
#  ['Torino', 'Udinese', 1],
#  ['Torino', 'Inter', -1],
#  ['Torino', 'Genoa', -1],
#  ['Torino', 'Frosinone', -1],
#  ['Torino', 'Fiorentina', -1],
#  ['Torino', 'Cagliari', -1],
#  ['Torino', 'Roma', -1],
#  ['Torino', 'Milan', -1],
#  ['Torino', 'Sampdoria', -1],
#  ['Sassuolo', 'Parma', -1],
#  ['Sassuolo', 'Empoli', -1],
#  ['Sassuolo', 'Bologna', -1],
#  ['Sassuolo', 'Atalanta', -1],
#  ['Sassuolo', 'Juventus', -1],
#  ['Sassuolo', 'Napoli', -1],
#  ['Sassuolo', 'Spal', 1],
#  ['Sassuolo', 'Udinese', 1],
#  ['Sassuolo', 'Inter', -1],
#  ['Sassuolo', 'Genoa', -1],
#  ['Sassuolo', 'Frosinone', -1],
#  ['Sassuolo', 'Fiorentina', -1],
#  ['Sassuolo', 'Cagliari', -1],
#  ['Sassuolo', 'Roma', -1],
#  ['Sassuolo', 'Milan', -1],
#  ['Sassuolo', 'Sampdoria', -1],
#  ['Parma', 'Empoli', -1],
#  ['Parma', 'Bologna', -1],
#  ['Parma', 'Atalanta', -1],
#  ['Parma', 'Juventus', -1],
#  ['Parma', 'Napoli', -1],
#  ['Parma', 'Spal', 1],
#  ['Parma', 'Udinese', 1],
#  ['Parma', 'Inter', -1],
#  ['Parma', 'Genoa', -1],
#  ['Parma', 'Frosinone', -1],
#  ['Parma', 'Fiorentina', -1],
#  ['Parma', 'Cagliari', -1],
#  ['Parma', 'Roma', 1],
#  ['Parma', 'Milan', -1],
#  ['Parma', 'Sampdoria', 1],
#  ['Empoli', 'Bologna', -1],
#  ['Empoli', 'Atalanta', -1],
#  ['Empoli', 'Juventus', 1],
#  ['Empoli', 'Napoli', 1],
#  ['Empoli', 'Spal', 1],
#  ['Empoli', 'Udinese', 1],
#  ['Empoli', 'Inter', 1],
#  ['Empoli', 'Genoa', 1],
#  ['Empoli', 'Frosinone', 1],
#  ['Empoli', 'Fiorentina', 1],
#  ['Empoli', 'Cagliari', -1],
#  ['Empoli', 'Roma', 1],
#  ['Empoli', 'Milan', 1],
#  ['Empoli', 'Sampdoria', 1],
#  ['Bologna', 'Atalanta', -1],
#  ['Bologna', 'Juventus', 1],
#  ['Bologna', 'Napoli', 1],
#  ['Bologna', 'Spal', 1],
#  ['Bologna', 'Udinese', 1],
#  ['Bologna', 'Inter', 1],
#  ['Bologna', 'Genoa', 1],
#  ['Bologna', 'Frosinone', 1],
#  ['Bologna', 'Fiorentina', 1],
#  ['Bologna', 'Cagliari', 1],
#  ['Bologna', 'Roma', 1],
#  ['Bologna', 'Milan', 1],
#  ['Bologna', 'Sampdoria', 1],
#  ['Atalanta', 'Juventus', 1],
#  ['Atalanta', 'Napoli', 1],
#  ['Atalanta', 'Spal', 1],
#  ['Atalanta', 'Udinese', 1],
#  ['Atalanta', 'Inter', 1],
#  ['Atalanta', 'Genoa', 1],
#  ['Atalanta', 'Frosinone', 1],
#  ['Atalanta', 'Fiorentina', 1],
#  ['Atalanta', 'Cagliari', 1],
#  ['Atalanta', 'Roma', 1],
#  ['Atalanta', 'Milan', 1],
#  ['Atalanta', 'Sampdoria', 1],
#  ['Juventus', 'Napoli', 1],
#  ['Juventus', 'Spal', 1],
#  ['Juventus', 'Udinese', 1],
#  ['Juventus', 'Inter', -1],
#  ['Juventus', 'Genoa', -1],
#  ['Juventus', 'Frosinone', -1],
#  ['Juventus', 'Fiorentina', -1],
#  ['Juventus', 'Cagliari', -1],
#  ['Juventus', 'Roma', 1],
#  ['Juventus', 'Milan', 1],
#  ['Juventus', 'Sampdoria', 1],
#  ['Napoli', 'Spal', 1],
#  ['Napoli', 'Udinese', 1],
#  ['Napoli', 'Inter', -1],
#  ['Napoli', 'Genoa', -1],
#  ['Napoli', 'Frosinone', -1],
#  ['Napoli', 'Fiorentina', -1],
#  ['Napoli', 'Cagliari', -1],
#  ['Napoli', 'Roma', 1],
#  ['Napoli', 'Milan', -1],
#  ['Napoli', 'Sampdoria', 1],
#  ['Spal', 'Udinese', 1],
#  ['Spal', 'Inter', -1],
#  ['Spal', 'Genoa', -1],
#  ['Spal', 'Frosinone', -1],
#  ['Spal', 'Fiorentina', -1],
#  ['Spal', 'Cagliari', -1],
#  ['Spal', 'Roma', -1],
#  ['Spal', 'Milan', -1],
#  ['Spal', 'Sampdoria', -1],
#  ['Udinese', 'Inter', -1],
#  ['Udinese', 'Genoa', -1],
#  ['Udinese', 'Frosinone', -1],
#  ['Udinese', 'Fiorentina', -1],
#  ['Udinese', 'Cagliari', -1],
#  ['Udinese', 'Roma', -1],
#  ['Udinese', 'Milan', -1],
#  ['Udinese', 'Sampdoria', -1],
#  ['Inter', 'Genoa', -1],
#  ['Inter', 'Frosinone', -1],
#  ['Inter', 'Fiorentina', -1],
#  ['Inter', 'Cagliari', -1],
#  ['Inter', 'Roma', 1],
#  ['Inter', 'Milan', 1],
#  ['Inter', 'Sampdoria', 1],
#  ['Genoa', 'Frosinone', -1],
#  ['Genoa', 'Fiorentina', -1],
#  ['Genoa', 'Cagliari', -1],
#  ['Genoa', 'Roma', 1],
#  ['Genoa', 'Milan', 1],
#  ['Genoa', 'Sampdoria', 1],
#  ['Frosinone', 'Fiorentina', -1],
#  ['Frosinone', 'Cagliari', -1],
#  ['Frosinone', 'Roma', 1],
#  ['Frosinone', 'Milan', 1],
#  ['Frosinone', 'Sampdoria', 1],
#  ['Fiorentina', 'Cagliari', -1],
#  ['Fiorentina', 'Roma', 1],
#  ['Fiorentina', 'Milan', 1],
#  ['Fiorentina', 'Sampdoria', 1],
#  ['Cagliari', 'Roma', 1],
#  ['Cagliari', 'Milan', 1],
#  ['Cagliari', 'Sampdoria', 1],
#  ['Roma', 'Milan', -1],
#  ['Roma', 'Sampdoria', 1],
#  ['Milan', 'Sampdoria', 1],
#  ['Lazio', 'Chievo', -1],
#  ['Torino', 'Chievo', -1],
#  ['Sassuolo', 'Chievo', -1],
#  ['Parma', 'Chievo', -1],
#  ['Empoli', 'Chievo', -1],
#  ['Bologna', 'Chievo', 1],
#  ['Atalanta', 'Chievo', 1],
#  ['Juventus', 'Chievo', -1],
#  ['Napoli', 'Chievo', -1],
#  ['Spal', 'Chievo', -1],
#  ['Udinese', 'Chievo', -1],
#  ['Inter', 'Chievo', -1],
#  ['Genoa', 'Chievo', -1],
#  ['Frosinone', 'Chievo', -1],
#  ['Fiorentina', 'Chievo', -1],
#  ['Cagliari', 'Chievo', 1],
#  ['Roma', 'Chievo', -1],
#  ['Milan', 'Chievo', -1],
#  ['Sampdoria', 'Chievo', -1],
#  ['Torino', 'Lazio', -1],
#  ['Sassuolo', 'Lazio', -1],
#  ['Parma', 'Lazio', -1],
#  ['Empoli', 'Lazio', 1],
#  ['Bologna', 'Lazio', 1],
#  ['Atalanta', 'Lazio', 1],
#  ['Juventus', 'Lazio', 1],
#  ['Napoli', 'Lazio', -1],
#  ['Spal', 'Lazio', -1],
#  ['Udinese', 'Lazio', -1],
#  ['Inter', 'Lazio', 1],
#  ['Genoa', 'Lazio', 1],
#  ['Frosinone', 'Lazio', 1],
#  ['Fiorentina', 'Lazio', 1],
#  ['Cagliari', 'Lazio', 1],
#  ['Roma', 'Lazio', -1],
#  ['Milan', 'Lazio', -1],
#  ['Sampdoria', 'Lazio', -1],
#  ['Sassuolo', 'Torino', 1],
#  ['Parma', 'Torino', 1],
#  ['Empoli', 'Torino', 1],
#  ['Bologna', 'Torino', 1],
#  ['Atalanta', 'Torino', 1],
#  ['Juventus', 'Torino', 1],
#  ['Napoli', 'Torino', 1],
#  ['Spal', 'Torino', 1],
#  ['Udinese', 'Torino', -1],
#  ['Inter', 'Torino', 1],
#  ['Genoa', 'Torino', 1],
#  ['Frosinone', 'Torino', 1],
#  ['Fiorentina', 'Torino', 1],
#  ['Cagliari', 'Torino', 1],
#  ['Roma', 'Torino', 1],
#  ['Milan', 'Torino', 1],
#  ['Sampdoria', 'Torino', 1],
#  ['Parma', 'Sassuolo', 1],
#  ['Empoli', 'Sassuolo', 1],
#  ['Bologna', 'Sassuolo', 1],
#  ['Atalanta', 'Sassuolo', 1],
#  ['Juventus', 'Sassuolo', 1],
#  ['Napoli', 'Sassuolo', 1],
#  ['Spal', 'Sassuolo', -1],
#  ['Udinese', 'Sassuolo', -1],
#  ['Inter', 'Sassuolo', 1],
#  ['Genoa', 'Sassuolo', 1],
#  ['Frosinone', 'Sassuolo', 1],
#  ['Fiorentina', 'Sassuolo', 1],
#  ['Cagliari', 'Sassuolo', 1],
#  ['Roma', 'Sassuolo', 1],
#  ['Milan', 'Sassuolo', 1],
#  ['Sampdoria', 'Sassuolo', 1],
#  ['Empoli', 'Parma', 1],
#  ['Bologna', 'Parma', 1],
#  ['Atalanta', 'Parma', 1],
#  ['Juventus', 'Parma', 1],
#  ['Napoli', 'Parma', 1],
#  ['Spal', 'Parma', -1],
#  ['Udinese', 'Parma', -1],
#  ['Inter', 'Parma', 1],
#  ['Genoa', 'Parma', 1],
#  ['Frosinone', 'Parma', 1],
#  ['Fiorentina', 'Parma', 1],
#  ['Cagliari', 'Parma', 1],
#  ['Roma', 'Parma', -1],
#  ['Milan', 'Parma', 1],
#  ['Sampdoria', 'Parma', -1],
#  ['Bologna', 'Empoli', 1],
#  ['Atalanta', 'Empoli', 1],
#  ['Juventus', 'Empoli', -1],
#  ['Napoli', 'Empoli', -1],
#  ['Spal', 'Empoli', -1],
#  ['Udinese', 'Empoli', -1],
#  ['Inter', 'Empoli', -1],
#  ['Genoa', 'Empoli', -1],
#  ['Frosinone', 'Empoli', -1],
#  ['Fiorentina', 'Empoli', -1],
#  ['Cagliari', 'Empoli', 1],
#  ['Roma', 'Empoli', -1],
#  ['Milan', 'Empoli', -1],
#  ['Sampdoria', 'Empoli', -1],
#  ['Atalanta', 'Bologna', 1],
#  ['Juventus', 'Bologna', -1],
#  ['Napoli', 'Bologna', -1],
#  ['Spal', 'Bologna', -1],
#  ['Udinese', 'Bologna', -1],
#  ['Inter', 'Bologna', -1],
#  ['Genoa', 'Bologna', -1],
#  ['Frosinone', 'Bologna', -1],
#  ['Fiorentina', 'Bologna', -1],
#  ['Cagliari', 'Bologna', -1],
#  ['Roma', 'Bologna', -1],
#  ['Milan', 'Bologna', -1],
#  ['Sampdoria', 'Bologna', -1],
#  ['Juventus', 'Atalanta', -1],
#  ['Napoli', 'Atalanta', -1],
#  ['Spal', 'Atalanta', -1],
#  ['Udinese', 'Atalanta', -1],
#  ['Inter', 'Atalanta', -1],
#  ['Genoa', 'Atalanta', -1],
#  ['Frosinone', 'Atalanta', -1],
#  ['Fiorentina', 'Atalanta', -1],
#  ['Cagliari', 'Atalanta', -1],
#  ['Roma', 'Atalanta', -1],
#  ['Milan', 'Atalanta', -1],
#  ['Sampdoria', 'Atalanta', -1],
#  ['Napoli', 'Juventus', -1],
#  ['Spal', 'Juventus', -1],
#  ['Udinese', 'Juventus', -1],
#  ['Inter', 'Juventus', 1],
#  ['Genoa', 'Juventus', 1],
#  ['Frosinone', 'Juventus', 1],
#  ['Fiorentina', 'Juventus', 1],
#  ['Cagliari', 'Juventus', 1],
#  ['Roma', 'Juventus', -1],
#  ['Milan', 'Juventus', -1],
#  ['Sampdoria', 'Juventus', -1],
#  ['Spal', 'Napoli', -1],
#  ['Udinese', 'Napoli', -1],
#  ['Inter', 'Napoli', 1],
#  ['Genoa', 'Napoli', 1],
#  ['Frosinone', 'Napoli', 1],
#  ['Fiorentina', 'Napoli', 1],
#  ['Cagliari', 'Napoli', 1],
#  ['Roma', 'Napoli', -1],
#  ['Milan', 'Napoli', 1],
#  ['Sampdoria', 'Napoli', -1],
#  ['Udinese', 'Spal', -1],
#  ['Inter', 'Spal', 1],
#  ['Genoa', 'Spal', 1],
#  ['Frosinone', 'Spal', 1],
#  ['Fiorentina', 'Spal', 1],
#  ['Cagliari', 'Spal', 1],
#  ['Roma', 'Spal', 1],
#  ['Milan', 'Spal', 1],
#  ['Sampdoria', 'Spal', 1],
#  ['Inter', 'Udinese', 1],
#  ['Genoa', 'Udinese', 1],
#  ['Frosinone', 'Udinese', 1],
#  ['Fiorentina', 'Udinese', 1],
#  ['Cagliari', 'Udinese', 1],
#  ['Roma', 'Udinese', 1],
#  ['Milan', 'Udinese', 1],
#  ['Sampdoria', 'Udinese', 1],
#  ['Genoa', 'Inter', 1],
#  ['Frosinone', 'Inter', 1],
#  ['Fiorentina', 'Inter', 1],
#  ['Cagliari', 'Inter', 1],
#  ['Roma', 'Inter', -1],
#  ['Milan', 'Inter', -1],
#  ['Sampdoria', 'Inter', -1],
#  ['Frosinone', 'Genoa', 1],
#  ['Fiorentina', 'Genoa', 1],
#  ['Cagliari', 'Genoa', 1],
#  ['Roma', 'Genoa', -1],
#  ['Milan', 'Genoa', -1],
#  ['Sampdoria', 'Genoa', -1],
#  ['Fiorentina', 'Frosinone', 1],
#  ['Cagliari', 'Frosinone', 1],
#  ['Roma', 'Frosinone', -1],
#  ['Milan', 'Frosinone', -1],
#  ['Sampdoria', 'Frosinone', -1],
#  ['Cagliari', 'Fiorentina', 1],
#  ['Roma', 'Fiorentina', -1],
#  ['Milan', 'Fiorentina', -1],
#  ['Sampdoria', 'Fiorentina', -1],
#  ['Roma', 'Cagliari', -1],
#  ['Milan', 'Cagliari', -1],
#  ['Sampdoria', 'Cagliari', -1],
#  ['Milan', 'Roma', 1],
#  ['Sampdoria', 'Roma', -1],
#  ['Sampdoria', 'Milan', -1]]

# %%
# Make dictionary of team stats (mean and variance) & list of all games with result
stats_dictionary, result_list = make_stats_dictionary('syntheticSerieA.csv', stats_dictionary={}, printable=0)

correct_predictions = 0
nr_of_draws = 0

''' 
UNCOMMENT THIS SECTION TO GET A RANDOMIXED ORDERING OF THE MATCHES. 
# 
If you want to randomize

'''

x = np.random.choice(range(len(result_list)), size=len(result_list), replace=False)
randomized_list = []
for i in x:
    randomized_list.append(result_list[i])
result_list = randomized_list

for i in range(len(result_list)):
    # result_list holds [team1, team2, result = score1 - score2]
    print(f"\nResult game {i}:   {result_list[i]}")
    team1 = result_list[i][0]
    team2 = result_list[i][1]
    
    print('team1: ', team1)
    print('team2: ', team2)
    result = result_list[i][2]
    
    # stats_dictionary with keyword 'teamname' and value [mean, variance]
    print(f"Stats before game: {stats_dictionary[team1]}, {stats_dictionary[team2]}")

    if result == 0:  # ignore tied games for now
        print("Game ignored due to tie")
        print(f"Stats after game:  {stats_dictionary[team1]}, {stats_dictionary[team2]}")
        nr_of_draws += 1
        print("Draws: ", nr_of_draws)
    else:
    
        # prediktera mat resultat och spara prediktion
        pred_result = predict_winner(team1, team2, stats_dictionary)
        
        if np.sign(result) == np.sign(pred_result):
                correct_predictions += 1
                print("Correct pred: ", correct_predictions)
        
        print('true result: ', result)
        print('pred result: ', pred_result)
                
        s_obs, t_obs =  gibbs_sampler(L=5000,
                                      player_1_stats=stats_dictionary[team1], 
                                      player_2_stats=stats_dictionary[team2],
                                      t_game=result)
        
        burn_in_value = 1000
        s_obs = s_obs[burn_in_value:]
        player_1_stats_posterior, player_2_stats_posterior = player_stats_estimate_from_obs(s_obs)
        
        
        # Update team stats so posterior makes new prior
        stats_dictionary[team1] = player_1_stats_posterior
        stats_dictionary[team2] = player_2_stats_posterior


        print(f"Stats AFTER game: {stats_dictionary[team1]}, {stats_dictionary[team2]}")

print()
print("correct_predictions ", correct_predictions)
print("reslist: ", len(result_list))
print("draws: ", nr_of_draws)
print('performance: ', correct_predictions / (len(result_list)-nr_of_draws))
# Out:
# Result game 0:   ['Inter', 'Cagliari', -1]
# team1:  Inter
# team2:  Cagliari
# Stats before game: [100, 1111.1111111111113], [100, 1111.1111111111113]
# 	 diff:  0
# true result:  -1
# pred result:  1
# Stats AFTER game: [70.7006757274811, 1085.715555142342], [128.22880628846198, 1084.8310195095082]
#
# Result game 1:   ['Roma', 'Juventus', -1]
# team1:  Roma
# team2:  Juventus
# Stats before game: [100, 1111.1111111111113], [100, 1111.1111111111113]
# 	 diff:  0
# true result:  -1
# pred result:  1
# Stats AFTER game: [43.3790885066012, 902.1955403250577], [155.4058108911944, 913.3828923834038]
#
# Result game 2:   ['Milan', 'Cagliari', -1]
# team1:  Milan
# team2:  Cagliari
# Stats before game: [100, 1111.1111111111113], [128.22880628846198, 1084.8310195095082]
# 	 diff:  -28.228806288461982
# Correct pred:  1
# true result:  -1
# pred result:  -1
# Stats AFTER game: [58.44776148324277, 1430.4746697515245], [168.03721926047032, 1407.1751170586433]
#
# Result game 3:   ['Fiorentina', 'Torino', 1]
# team1:  Fiorentina
# team2:  Torino
# Stats before game: [100, 1111.1111111111113], [100, 1111.1111111111113]
# 	 diff:  0
# Correct pred:  2
# true result:  1
# pred result:  1
# Stats AFTER game: [123.53996682183715, 816.7879376383247], [76.24498805219605, 837.8395371650446]
#
# Result game 4:   ['Milan', 'Udinese', 1]
# team1:  Milan
# team2:  Udinese
# Stats before game: [58.44776148324277, 1430.4746697515245], [100, 1111.1111111111113]
# 	 diff:  -41.55223851675723
# true result:  1
# pred result:  -1
# Stats AFTER game: [101.02164252745368, 851.4161150275042], [66.77388407739211, 759.8295863926644]
#
# Result game 5:   ['Udinese', 'Inter', -1]
# team1:  Udinese
# team2:  Inter
# Stats before game: [66.77388407739211, 759.8295863926644], [70.7006757274811, 1085.715555142342]
# 	 diff:  -3.926791650088987
# Correct pred:  3
# true result:  -1
# pred result:  -1
# Stats AFTER game: [52.78116194370792, 613.6167378170808], [90.20985293606124, 806.9178314794312]
#
# Result game 6:   ['Fiorentina', 'Roma', 1]
# team1:  Fiorentina
# team2:  Roma
# Stats before game: [123.53996682183715, 816.7879376383247], [43.3790885066012, 902.1955403250577]
# 	 diff:  80.16087831523595
# Correct pred:  4
# true result:  1
# pred result:  1
# Stats AFTER game: [117.7236794334643, 736.3217894558958], [50.511337317422345, 756.4492921669819]
#
# Result game 7:   ['Sampdoria', 'Parma', -1]
# team1:  Sampdoria
# team2:  Parma
# Stats before game: [100, 1111.1111111111113], [100, 1111.1111111111113]
# 	 diff:  0
# true result:  -1
# pred result:  1
# Stats AFTER game: [69.64076075897566, 881.14654572196], [129.9829254638972, 892.6485461543214]
#
# Result game 8:   ['Parma', 'Sampdoria', 1]
# team1:  Parma
# team2:  Sampdoria
# Stats before game: [129.9829254638972, 892.6485461543214], [69.64076075897566, 881.14654572196]
# 	 diff:  60.342164704921544
# Correct pred:  5
# true result:  1
# pred result:  1
# Stats AFTER game: [118.63717314374593, 621.3644586913821], [80.28134413578478, 615.4350923530386]
#
# Result game 9:   ['Spal', 'Udinese', 1]
# team1:  Spal
# team2:  Udinese
# Stats before game: [100, 1111.1111111111113], [52.78116194370792, 613.6167378170808]
# 	 diff:  47.21883805629208
# Correct pred:  6
# true result:  1
# pred result:  1
# Stats AFTER game: [115.98702417964567, 944.0448763770521], [44.7767654687855, 583.2604775519585]
#
# Result game 10:   ['Parma', 'Chievo', -1]
# team1:  Parma
# team2:  Chievo
# Stats before game: [118.63717314374593, 621.3644586913821], [100, 1111.1111111111113]
# 	 diff:  18.637173143745926
# true result:  -1
# pred result:  1
# Stats AFTER game: [102.80237644626011, 447.36417112237876], [127.94925986390658, 550.0415908409813]
#
# Result game 11:   ['Fiorentina', 'Spal', 1]
# team1:  Fiorentina
# team2:  Spal
# Stats before game: [117.7236794334643, 736.3217894558958], [115.98702417964567, 944.0448763770521]
# 	 diff:  1.7366552538186255
# Correct pred:  7
# true result:  1
# pred result:  1
# Stats AFTER game: [140.6034615895622, 741.4415351815408], [85.97063624231316, 931.3469496600779]
#
# Result game 12:   ['Sampdoria', 'Udinese', 1]
# team1:  Sampdoria
# team2:  Udinese
# Stats before game: [80.28134413578478, 615.4350923530386], [44.7767654687855, 583.2604775519585]
# 	 diff:  35.50457866699928
# Correct pred:  8
# true result:  1
# pred result:  1
# Stats AFTER game: [89.57108230341615, 704.721178326834], [35.67979492565291, 665.7895467788352]
#
# Result game 13:   ['Chievo', 'Fiorentina', 1]
# team1:  Chievo
# team2:  Fiorentina
# Stats before game: [127.94925986390658, 550.0415908409813], [140.6034615895622, 741.4415351815408]
# 	 diff:  -12.65420172565561
# true result:  1
# pred result:  -1
# Stats AFTER game: [147.6182752713689, 404.0300854615464], [114.37117065306072, 458.7996385037485]
#
# Result game 14:   ['Fiorentina', 'Milan', 1]
# team1:  Fiorentina
# team2:  Milan
# Stats before game: [114.37117065306072, 458.7996385037485], [101.02164252745368, 851.4161150275042]
# 	 diff:  13.349528125607037
# Correct pred:  9
# true result:  1
# pred result:  1
# Stats AFTER game: [128.38636643529432, 392.69740179070556], [77.24171150330905, 614.5409158199924]
#
# Result game 15:   ['Sassuolo', 'Sampdoria', -1]
# team1:  Sassuolo
# team2:  Sampdoria
# Stats before game: [100, 1111.1111111111113], [89.57108230341615, 704.721178326834]
# 	 diff:  10.428917696583852
# true result:  -1
# pred result:  1
# Stats AFTER game: [65.73846831704492, 899.945717855762], [110.80572912269201, 622.478980498448]
#
# Result game 16:   ['Napoli', 'Parma', 1]
# team1:  Napoli
# team2:  Parma
# Stats before game: [100, 1111.1111111111113], [102.80237644626011, 447.36417112237876]
# 	 diff:  -2.802376446260112
# true result:  1
# pred result:  -1
# Stats AFTER game: [125.93617706055828, 614.5397075490243], [92.39420026485894, 372.45012007576116]
#
# Result game 17:   ['Torino', 'Spal', -1]
# team1:  Torino
# team2:  Spal
# Stats before game: [76.24498805219605, 837.8395371650446], [85.97063624231316, 931.3469496600779]
# 	 diff:  -9.725648190117113
# Correct pred:  10
# true result:  -1
# pred result:  -1
# Stats AFTER game: [38.93429422034063, 1150.4935284893984], [126.74344608073032, 1335.362854685351]
#
# Result game 18:   ['Milan', 'Fiorentina', -1]
# team1:  Milan
# team2:  Fiorentina
# Stats before game: [77.24171150330905, 614.5409158199924], [128.38636643529432, 392.69740179070556]
# 	 diff:  -51.14465493198527
# Correct pred:  11
# true result:  -1
# pred result:  -1
# Stats AFTER game: [79.97345634003263, 587.1132472325081], [126.11427998372936, 382.2567027884551]
#
# Result game 19:   ['Bologna', 'Frosinone', 1]
# team1:  Bologna
# team2:  Frosinone
# Stats before game: [100, 1111.1111111111113], [100, 1111.1111111111113]
# 	 diff:  0
# Correct pred:  12
# true result:  1
# pred result:  1
# Stats AFTER game: [131.00370666275774, 1040.063775817765], [68.84306982066627, 1030.551673446652]
#
# Result game 20:   ['Sassuolo', 'Parma', -1]
# team1:  Sassuolo
# team2:  Parma
# Stats before game: [65.73846831704492, 899.945717855762], [92.39420026485894, 372.45012007576116]
# 	 diff:  -26.65573194781402
# Correct pred:  13
# true result:  -1
# pred result:  -1
# Stats AFTER game: [56.05123661812152, 547.8420356285922], [96.24030657865782, 301.2502159980056]
#
# Result game 21:   ['Inter', 'Empoli', -1]
# team1:  Inter
# team2:  Empoli
# Stats before game: [90.20985293606124, 806.9178314794312], [100, 1111.1111111111113]
# 	 diff:  -9.790147063938761
# Correct pred:  14
# true result:  -1
# pred result:  -1
# Stats AFTER game: [62.49987721036101, 662.9661279101321], [137.85045685583052, 831.03824145551]
#
# Result game 22:   ['Parma', 'Napoli', -1]
# team1:  Parma
# team2:  Napoli
# Stats before game: [96.24030657865782, 301.2502159980056], [125.93617706055828, 614.5397075490243]
# 	 diff:  -29.695870481900457
# Correct pred:  15
# true result:  -1
# pred result:  -1
# Stats AFTER game: [85.2602230532504, 299.3931565320712], [148.64343101061408, 581.7008469575777]
#
# Result game 23:   ['Sassuolo', 'Chievo', -1]
# team1:  Sassuolo
# team2:  Chievo
# Stats before game: [56.05123661812152, 547.8420356285922], [147.6182752713689, 404.0300854615464]
# 	 diff:  -91.56703865324738
# Correct pred:  16
# true result:  -1
# pred result:  -1
# Stats AFTER game: [55.540832784938914, 665.6896797356281], [147.5955513000799, 466.4729163604812]
#
# Result game 24:   ['Fiorentina', 'Chievo', -1]
# team1:  Fiorentina
# team2:  Chievo
# Stats before game: [126.11427998372936, 382.2567027884551], [147.5955513000799, 466.4729163604812]
# 	 diff:  -21.481271316350544
# Correct pred:  17
# true result:  -1
# pred result:  -1
# Stats AFTER game: [121.88998143974293, 291.7877135964406], [152.14618440642994, 314.9969414469825]
#
# Result game 25:   ['Napoli', 'Udinese', 1]
# team1:  Napoli
# team2:  Udinese
# Stats before game: [148.64343101061408, 581.7008469575777], [35.67979492565291, 665.7895467788352]
# 	 diff:  112.96363608496117
# Correct pred:  18
# true result:  1
# pred result:  1
# Stats AFTER game: [149.3596922681944, 698.1347063829497], [34.98338348394151, 835.7630102197148]
#
# Result game 26:   ['Sassuolo', 'Inter', -1]
# team1:  Sassuolo
# team2:  Inter
# Stats before game: [55.540832784938914, 665.6896797356281], [62.49987721036101, 662.9661279101321]
# 	 diff:  -6.959044425422093
# Correct pred:  19
# true result:  -1
# pred result:  -1
# Stats AFTER game: [42.14542644414669, 463.12097949069505], [74.77126033024437, 476.45233549637936]
#
# Result game 27:   ['Napoli', 'Frosinone', -1]
# team1:  Napoli
# team2:  Frosinone
# Stats before game: [149.3596922681944, 698.1347063829497], [68.84306982066627, 1030.551673446652]
# 	 diff:  80.51662244752814
# true result:  -1
# pred result:  1
# Stats AFTER game: [105.9412719615596, 505.79915128509305], [133.55879284830678, 612.9723237075098]
#
# Result game 28:   ['Milan', 'Inter', -1]
# team1:  Milan
# team2:  Inter
# Stats before game: [79.97345634003263, 587.1132472325081], [74.77126033024437, 476.45233549637936]
# 	 diff:  5.202196009788253
# true result:  -1
# pred result:  1
# Stats AFTER game: [62.15164901101257, 371.21662758129685], [89.40022726425255, 333.0248893777061]
#
# Result game 29:   ['Torino', 'Parma', -1]
# team1:  Torino
# team2:  Parma
# Stats before game: [38.93429422034063, 1150.4935284893984], [85.2602230532504, 299.3931565320712]
# 	 diff:  -46.32592883290977
# Correct pred:  20
# true result:  -1
# pred result:  -1
# Stats AFTER game: [13.889788098947374, 1268.59271595332], [91.98788176741493, 316.1799199680247]
#
# Result game 30:   ['Napoli', 'Bologna', -1]
# team1:  Napoli
# team2:  Bologna
# Stats before game: [105.9412719615596, 505.79915128509305], [131.00370666275774, 1040.063775817765]
# 	 diff:  -25.062434701198143
# Correct pred:  21
# true result:  -1
# pred result:  -1
# Stats AFTER game: [93.61021562762781, 522.5396925808946], [156.6930155069441, 1134.100990724556]
#
# Result game 31:   ['Cagliari', 'Chievo', 1]
# team1:  Cagliari
# team2:  Chievo
# Stats before game: [168.03721926047032, 1407.1751170586433], [152.14618440642994, 314.9969414469825]
# 	 diff:  15.891034854040385
# Correct pred:  22
# true result:  1
# pred result:  1
# Stats AFTER game: [199.4802713187044, 951.0204104350604], [145.16911053719028, 295.4368384658118]
#
# Result game 32:   ['Atalanta', 'Spal', 1]
# team1:  Atalanta
# team2:  Spal
# Stats before game: [100, 1111.1111111111113], [126.74344608073032, 1335.362854685351]
# 	 diff:  -26.743446080730322
# true result:  1
# pred result:  -1
# Stats AFTER game: [136.67203587049386, 832.3962586525528], [82.71017415776734, 963.1679028734535]
#
# Result game 33:   ['Frosinone', 'Fiorentina', -1]
# team1:  Frosinone
# team2:  Fiorentina
# Stats before game: [133.55879284830678, 612.9723237075098], [121.88998143974293, 291.7877135964406]
# 	 diff:  11.668811408563855
# true result:  -1
# pred result:  1
# Stats AFTER game: [106.40902979958625, 521.6531095922421], [134.4677450070578, 257.04903128668]
#
# Result game 34:   ['Sassuolo', 'Spal', 1]
# team1:  Sassuolo
# team2:  Spal
# Stats before game: [42.14542644414669, 463.12097949069505], [82.71017415776734, 963.1679028734535]
# 	 diff:  -40.56474771362065
# true result:  1
# pred result:  -1
# Stats AFTER game: [67.56069736589369, 386.68815814063277], [30.385976289350513, 597.390234456354]
#
# Result game 35:   ['Empoli', 'Genoa', 1]
# team1:  Empoli
# team2:  Genoa
# Stats before game: [137.85045685583052, 831.03824145551], [100, 1111.1111111111113]
# 	 diff:  37.850456855830515
# Correct pred:  23
# true result:  1
# pred result:  1
# Stats AFTER game: [142.48874130191044, 635.337684387912], [93.11048575104438, 754.637087032021]
#
# Result game 36:   ['Lazio', 'Juventus', -1]
# team1:  Lazio
# team2:  Juventus
# Stats before game: [100, 1111.1111111111113], [155.4058108911944, 913.3828923834038]
# 	 diff:  -55.40581089119439
# Correct pred:  24
# true result:  -1
# pred result:  -1
# Stats AFTER game: [80.15204478171896, 1259.3818298214358], [172.31432260066885, 1030.682925288417]
#
# Result game 37:   ['Torino', 'Juventus', -1]
# team1:  Torino
# team2:  Juventus
# Stats before game: [13.889788098947374, 1268.59271595332], [172.31432260066885, 1030.682925288417]
# 	 diff:  -158.42453450172147
# Correct pred:  25
# true result:  -1
# pred result:  -1
# Stats AFTER game: [6.786658079749458, 1051.8718382154852], [178.43241173454706, 918.9095846983713]
#
# Result game 38:   ['Torino', 'Sassuolo', -1]
# team1:  Torino
# team2:  Sassuolo
# Stats before game: [6.786658079749458, 1051.8718382154852], [67.56069736589369, 386.68815814063277]
# 	 diff:  -60.77403928614423
# Correct pred:  26
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-4.217638353266528, 1507.0080333731644], [71.65482281387267, 454.9284778074544]
#
# Result game 39:   ['Roma', 'Cagliari', -1]
# team1:  Roma
# team2:  Cagliari
# Stats before game: [50.511337317422345, 756.4492921669819], [199.4802713187044, 951.0204104350604]
# 	 diff:  -148.96893400128207
# Correct pred:  27
# true result:  -1
# pred result:  -1
# Stats AFTER game: [71.41002196450128, 782.5097320349394], [173.68304693353508, 983.7726846797261]
#
# Result game 40:   ['Bologna', 'Sampdoria', 1]
# team1:  Bologna
# team2:  Sampdoria
# Stats before game: [156.6930155069441, 1134.100990724556], [110.80572912269201, 622.478980498448]
# 	 diff:  45.88728638425209
# Correct pred:  28
# true result:  1
# pred result:  1
# Stats AFTER game: [154.73958032093756, 793.4966251494899], [111.71877600570596, 507.32243099072576]
#
# Result game 41:   ['Juventus', 'Napoli', 1]
# team1:  Juventus
# team2:  Napoli
# Stats before game: [178.43241173454706, 918.9095846983713], [93.61021562762781, 522.5396925808946]
# 	 diff:  84.82219610691925
# Correct pred:  29
# true result:  1
# pred result:  1
# Stats AFTER game: [187.77014156872983, 780.9426318867661], [87.68757836810686, 485.76968024649216]
#
# Result game 42:   ['Empoli', 'Sassuolo', 1]
# team1:  Empoli
# team2:  Sassuolo
# Stats before game: [142.48874130191044, 635.337684387912], [71.65482281387267, 454.9284778074544]
# 	 diff:  70.83391848803777
# Correct pred:  30
# true result:  1
# pred result:  1
# Stats AFTER game: [138.28744950516656, 610.041588184952], [74.52845529736895, 428.22514851371]
#
# Result game 43:   ['Sassuolo', 'Genoa', -1]
# team1:  Sassuolo
# team2:  Genoa
# Stats before game: [74.52845529736895, 428.22514851371], [93.11048575104438, 754.637087032021]
# 	 diff:  -18.58203045367543
# Correct pred:  31
# true result:  -1
# pred result:  -1
# Stats AFTER game: [65.14626540152244, 361.6799252271653], [109.73599941609716, 534.2780639358513]
#
# Result game 44:   ['Cagliari', 'Spal', 1]
# team1:  Cagliari
# team2:  Spal
# Stats before game: [173.68304693353508, 983.7726846797261], [30.385976289350513, 597.390234456354]
# 	 diff:  143.29707064418457
# Correct pred:  32
# true result:  1
# pred result:  1
# Stats AFTER game: [177.46097772759788, 1362.7898634423432], [28.55939009512941, 742.7774689282624]
#
# Result game 45:   ['Fiorentina', 'Cagliari', -1]
# team1:  Fiorentina
# team2:  Cagliari
# Stats before game: [134.4677450070578, 257.04903128668], [177.46097772759788, 1362.7898634423432]
# 	 diff:  -42.99323272054008
# Correct pred:  33
# true result:  -1
# pred result:  -1
# Stats AFTER game: [129.05906875363272, 293.95140706871183], [205.90839775983932, 2468.9357403656686]
#
# Result game 46:   ['Sassuolo', 'Torino', 1]
# team1:  Sassuolo
# team2:  Torino
# Stats before game: [65.14626540152244, 361.6799252271653], [-4.217638353266528, 1507.0080333731644]
# 	 diff:  69.36390375478896
# Correct pred:  34
# true result:  1
# pred result:  1
# Stats AFTER game: [66.75099891480737, 393.15939512721343], [-10.483942099215302, 1830.869791955578]
#
# Result game 47:   ['Napoli', 'Cagliari', -1]
# team1:  Napoli
# team2:  Cagliari
# Stats before game: [87.68757836810686, 485.76968024649216], [205.90839775983932, 2468.9357403656686]
# 	 diff:  -118.22081939173246
# Correct pred:  35
# true result:  -1
# pred result:  -1
# Stats AFTER game: [90.6159050657311, 507.6513441816483], [190.85956550909432, 3227.736202491844]
#
# Result game 48:   ['Udinese', 'Milan', -1]
# team1:  Udinese
# team2:  Milan
# Stats before game: [34.98338348394151, 835.7630102197148], [62.15164901101257, 371.21662758129685]
# 	 diff:  -27.168265527071064
# Correct pred:  36
# true result:  -1
# pred result:  -1
# Stats AFTER game: [29.545698750440135, 523.032742181298], [64.33248027132451, 307.541602118475]
#
# Result game 49:   ['Torino', 'Genoa', -1]
# team1:  Torino
# team2:  Genoa
# Stats before game: [-10.483942099215302, 1830.869791955578], [109.73599941609716, 534.2780639358513]
# 	 diff:  -120.21994151531246
# Correct pred:  37
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-31.53500241484905, 4469.634781057496], [115.32367021904857, 773.4396258694151]
#
# Result game 50:   ['Spal', 'Lazio', -1]
# team1:  Spal
# team2:  Lazio
# Stats before game: [28.55939009512941, 742.7774689282624], [80.15204478171896, 1259.3818298214358]
# 	 diff:  -51.59265468658955
# Correct pred:  38
# true result:  -1
# pred result:  -1
# Stats AFTER game: [23.796558733539758, 713.222330913039], [87.75008931199447, 1196.6554743592696]
#
# Result game 51:   ['Genoa', 'Udinese', 1]
# team1:  Genoa
# team2:  Udinese
# Stats before game: [115.32367021904857, 773.4396258694151], [29.545698750440135, 523.032742181298]
# 	 diff:  85.77797146860843
# Correct pred:  39
# true result:  1
# pred result:  1
# Stats AFTER game: [110.63099156028993, 656.6246630291079], [32.061417301381944, 458.41000305632457]
#
# Result game 52:   ['Torino', 'Inter', -1]
# team1:  Torino
# team2:  Inter
# Stats before game: [-31.53500241484905, 4469.634781057496], [89.40022726425255, 333.0248893777061]
# 	 diff:  -120.9352296791016
# Correct pred:  40
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-49.342788570578655, 3878.0170521250643], [91.05089792428745, 329.54169512436295]
#
# Result game 53:   ['Sassuolo', 'Juventus', -1]
# team1:  Sassuolo
# team2:  Juventus
# Stats before game: [66.75099891480737, 393.15939512721343], [187.77014156872983, 780.9426318867661]
# 	 diff:  -121.01914265392246
# Correct pred:  41
# true result:  -1
# pred result:  -1
# Stats AFTER game: [60.498873358897804, 421.6476888868772], [199.77095714628396, 977.2296698520162]
#
# Result game 54:   ['Fiorentina', 'Inter', 1]
# team1:  Fiorentina
# team2:  Inter
# Stats before game: [129.05906875363272, 293.95140706871183], [91.05089792428745, 329.54169512436295]
# 	 diff:  38.00817082934526
# Correct pred:  42
# true result:  1
# pred result:  1
# Stats AFTER game: [124.9310483213745, 272.5393527212744], [95.73916252822725, 315.5766097699901]
#
# Result game 55:   ['Napoli', 'Roma', 1]
# team1:  Napoli
# team2:  Roma
# Stats before game: [90.6159050657311, 507.6513441816483], [71.41002196450128, 782.5097320349394]
# 	 diff:  19.205883101229816
# Correct pred:  43
# true result:  1
# pred result:  1
# Stats AFTER game: [104.85716980036459, 549.9873372593053], [48.23036465920716, 905.7144929111302]
#
# Result game 56:   ['Chievo', 'Inter', 1]
# team1:  Chievo
# team2:  Inter
# Stats before game: [145.16911053719028, 295.4368384658118], [95.73916252822725, 315.5766097699901]
# 	 diff:  49.429948008963024
# Correct pred:  44
# true result:  1
# pred result:  1
# Stats AFTER game: [149.67957674106202, 492.60145167023927], [90.87412369344864, 529.4647685865315]
#
# Result game 57:   ['Bologna', 'Sassuolo', 1]
# team1:  Bologna
# team2:  Sassuolo
# Stats before game: [154.73958032093756, 793.4966251494899], [60.498873358897804, 421.6476888868772]
# 	 diff:  94.24070696203975
# Correct pred:  45
# true result:  1
# pred result:  1
# Stats AFTER game: [163.93960287832883, 881.5611350549212], [55.87536621745027, 433.41272281010833]
#
# Result game 58:   ['Torino', 'Lazio', -1]
# team1:  Torino
# team2:  Lazio
# Stats before game: [-49.342788570578655, 3878.0170521250643], [87.75008931199447, 1196.6554743592696]
# 	 diff:  -137.09287788257313
# Correct pred:  46
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-14.592278983392426, 2430.4003997143873], [76.83508032249435, 1029.917099341711]
#
# Result game 59:   ['Frosinone', 'Parma', 1]
# team1:  Frosinone
# team2:  Parma
# Stats before game: [106.40902979958625, 521.6531095922421], [91.98788176741493, 316.1799199680247]
# 	 diff:  14.421148032171317
# Correct pred:  47
# true result:  1
# pred result:  1
# Stats AFTER game: [130.29612747185718, 683.2914191995645], [77.29440991488272, 365.5750281230831]
#
# Result game 60:   ['Spal', 'Chievo', -1]
# team1:  Spal
# team2:  Chievo
# Stats before game: [23.796558733539758, 713.222330913039], [149.67957674106202, 492.60145167023927]
# 	 diff:  -125.88301800752227
# Correct pred:  48
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-0.44725422134406995, 840.1477315048094], [165.88257210896754, 588.635304329299]
#
# Result game 61:   ['Fiorentina', 'Empoli', -1]
# team1:  Fiorentina
# team2:  Empoli
# Stats before game: [124.9310483213745, 272.5393527212744], [138.28744950516656, 610.041588184952]
# 	 diff:  -13.356401183792059
# Correct pred:  49
# true result:  -1
# pred result:  -1
# Stats AFTER game: [114.8561506533139, 259.17721702401843], [160.80619198112421, 528.0753069907477]
#
# Result game 62:   ['Frosinone', 'Inter', 1]
# team1:  Frosinone
# team2:  Inter
# Stats before game: [130.29612747185718, 683.2914191995645], [90.87412369344864, 529.4647685865315]
# 	 diff:  39.42200377840854
# Correct pred:  50
# true result:  1
# pred result:  1
# Stats AFTER game: [150.23555812497185, 540.7727034674648], [75.94948087866133, 423.8979338234831]
#
# Result game 63:   ['Torino', 'Frosinone', -1]
# team1:  Torino
# team2:  Frosinone
# Stats before game: [-14.592278983392426, 2430.4003997143873], [150.23555812497185, 540.7727034674648]
# 	 diff:  -164.82783710836426
# Correct pred:  51
# true result:  -1
# pred result:  -1
# Stats AFTER game: [8.768267249682932, 4133.54609501892], [145.394371380274, 622.7387898337093]
#
# Result game 64:   ['Spal', 'Sampdoria', -1]
# team1:  Spal
# team2:  Sampdoria
# Stats before game: [-0.44725422134406995, 840.1477315048094], [111.71877600570596, 507.32243099072576]
# 	 diff:  -112.16603022705003
# Correct pred:  52
# true result:  -1
# pred result:  -1
# Stats AFTER game: [20.376973000122263, 1399.768038538885], [98.71685008115007, 738.0665634791902]
#
# Result game 65:   ['Parma', 'Spal', 1]
# team1:  Parma
# team2:  Spal
# Stats before game: [77.29440991488272, 365.5750281230831], [20.376973000122263, 1399.768038538885]
# 	 diff:  56.91743691476046
# Correct pred:  53
# true result:  1
# pred result:  1
# Stats AFTER game: [78.63616978359528, 370.6650894876588], [13.15915368808626, 1641.410203907724]
#
# Result game 66:   ['Inter', 'Atalanta', -1]
# team1:  Inter
# team2:  Atalanta
# Stats before game: [75.94948087866133, 423.8979338234831], [136.67203587049386, 832.3962586525528]
# 	 diff:  -60.722554991832524
# Correct pred:  54
# true result:  -1
# pred result:  -1
# Stats AFTER game: [64.96041877361424, 487.71296800084735], [156.76905234651068, 1115.8027287068576]
#
# Result game 67:   ['Cagliari', 'Empoli', 1]
# team1:  Cagliari
# team2:  Empoli
# Stats before game: [190.85956550909432, 3227.736202491844], [160.80619198112421, 528.0753069907477]
# 	 diff:  30.05337352797011
# Correct pred:  55
# true result:  1
# pred result:  1
# Stats AFTER game: [205.44727005309042, 1964.2898148434738], [158.659620400153, 497.7585969038946]
#
# Result game 68:   ['Inter', 'Bologna', -1]
# team1:  Inter
# team2:  Bologna
# Stats before game: [64.96041877361424, 487.71296800084735], [163.93960287832883, 881.5611350549212]
# 	 diff:  -98.97918410471459
# Correct pred:  56
# true result:  -1
# pred result:  -1
# Stats AFTER game: [73.5150440920358, 456.2871143799713], [147.71679484272303, 776.2022700969663]
#
# Result game 69:   ['Cagliari', 'Frosinone', 1]
# team1:  Cagliari
# team2:  Frosinone
# Stats before game: [205.44727005309042, 1964.2898148434738], [145.394371380274, 622.7387898337093]
# 	 diff:  60.05289867281641
# Correct pred:  57
# true result:  1
# pred result:  1
# Stats AFTER game: [220.6345606930966, 1643.152160938599], [141.31028852783442, 590.3551211744095]
#
# Result game 70:   ['Frosinone', 'Genoa', 1]
# team1:  Frosinone
# team2:  Genoa
# Stats before game: [141.31028852783442, 590.3551211744095], [110.63099156028993, 656.6246630291079]
# 	 diff:  30.679296967544488
# Correct pred:  58
# true result:  1
# pred result:  1
# Stats AFTER game: [159.37325637625943, 878.198592333264], [90.16538393081467, 1008.1411942880902]
#
# Result game 71:   ['Udinese', 'Empoli', -1]
# team1:  Udinese
# team2:  Empoli
# Stats before game: [32.061417301381944, 458.41000305632457], [158.659620400153, 497.7585969038946]
# 	 diff:  -126.59820309877105
# Correct pred:  59
# true result:  -1
# pred result:  -1
# Stats AFTER game: [35.39043197281514, 632.4340818432352], [155.00880079844796, 719.369049688138]
#
# Result game 72:   ['Milan', 'Parma', 1]
# team1:  Milan
# team2:  Parma
# Stats before game: [64.33248027132451, 307.541602118475], [78.63616978359528, 370.6650894876588]
# 	 diff:  -14.303689512270765
# true result:  1
# pred result:  -1
# Stats AFTER game: [81.29070216772824, 226.7769792808256], [58.320015551525415, 261.10541182630766]
#
# Result game 73:   ['Chievo', 'Sassuolo', 1]
# team1:  Chievo
# team2:  Sassuolo
# Stats before game: [165.88257210896754, 588.635304329299], [55.87536621745027, 433.41272281010833]
# 	 diff:  110.00720589151726
# Correct pred:  60
# true result:  1
# pred result:  1
# Stats AFTER game: [149.93054945614634, 800.7962958952203], [68.35594007435665, 531.6413515115951]
#
# Result game 74:   ['Lazio', 'Sampdoria', 1]
# team1:  Lazio
# team2:  Sampdoria
# Stats before game: [76.83508032249435, 1029.917099341711], [98.71685008115007, 738.0665634791902]
# 	 diff:  -21.88176975865572
# true result:  1
# pred result:  -1
# Stats AFTER game: [110.83935888166982, 651.3003286979285], [74.15967695759016, 532.2812535158827]
#
# Result game 75:   ['Fiorentina', 'Napoli', 1]
# team1:  Fiorentina
# team2:  Napoli
# Stats before game: [114.8561506533139, 259.17721702401843], [104.85716980036459, 549.9873372593053]
# 	 diff:  9.998980852949316
# Correct pred:  61
# true result:  1
# pred result:  1
# Stats AFTER game: [122.22023302652053, 224.71745647838765], [88.69047824005064, 429.0796512892649]
#
# Result game 76:   ['Atalanta', 'Torino', 1]
# team1:  Atalanta
# team2:  Torino
# Stats before game: [156.76905234651068, 1115.8027287068576], [8.768267249682932, 4133.54609501892]
# 	 diff:  148.00078509682774
# Correct pred:  62
# true result:  1
# pred result:  1
# Stats AFTER game: [152.18620051703175, 998.941039008543], [24.309124626536203, 2424.486953079016]
#
# Result game 77:   ['Atalanta', 'Milan', 1]
# team1:  Atalanta
# team2:  Milan
# Stats before game: [152.18620051703175, 998.941039008543], [81.29070216772824, 226.7769792808256]
# 	 diff:  70.89549834930351
# Correct pred:  63
# true result:  1
# pred result:  1
# Stats AFTER game: [130.75276547483594, 552.3261377543062], [86.12713494657157, 203.71846747934327]
#
# Result game 78:   ['Sampdoria', 'Milan', -1]
# team1:  Sampdoria
# team2:  Milan
# Stats before game: [74.15967695759016, 532.2812535158827], [86.12713494657157, 203.71846747934327]
# 	 diff:  -11.967457988981408
# Correct pred:  64
# true result:  -1
# pred result:  -1
# Stats AFTER game: [61.751037306011526, 338.6367735908977], [90.68986274754056, 168.94878322507958]
#
# Result game 79:   ['Udinese', 'Frosinone', -1]
# team1:  Udinese
# team2:  Frosinone
# Stats before game: [35.39043197281514, 632.4340818432352], [159.37325637625943, 878.198592333264]
# 	 diff:  -123.98282440344428
# Correct pred:  65
# true result:  -1
# pred result:  -1
# Stats AFTER game: [23.4017591991252, 927.8801482482502], [176.44577986179834, 1447.7996053477236]
#
# Result game 80:   ['Inter', 'Lazio', 1]
# team1:  Inter
# team2:  Lazio
# Stats before game: [73.5150440920358, 456.2871143799713], [110.83935888166982, 651.3003286979285]
# 	 diff:  -37.32431478963403
# true result:  1
# pred result:  -1
# Stats AFTER game: [101.15586311830323, 381.4866874862922], [72.13412142375488, 507.0531646563475]
#
# Result game 81:   ['Genoa', 'Spal', 1]
# team1:  Genoa
# team2:  Spal
# Stats before game: [90.16538393081467, 1008.1411942880902], [13.15915368808626, 1641.410203907724]
# 	 diff:  77.0062302427284
# Correct pred:  66
# true result:  1
# pred result:  1
# Stats AFTER game: [82.2338931763516, 760.0507631276006], [26.32961288648155, 1017.5116393548969]
#
# Result game 82:   ['Napoli', 'Lazio', -1]
# team1:  Napoli
# team2:  Lazio
# Stats before game: [88.69047824005064, 429.0796512892649], [72.13412142375488, 507.0531646563475]
# 	 diff:  16.55635681629576
# true result:  -1
# pred result:  1
# Stats AFTER game: [71.28379054236997, 302.8954126603443], [93.01283950975775, 334.09254112998235]
#
# Result game 83:   ['Chievo', 'Spal', 1]
# team1:  Chievo
# team2:  Spal
# Stats before game: [149.93054945614634, 800.7962958952203], [26.32961288648155, 1017.5116393548969]
# 	 diff:  123.60093656966478
# Correct pred:  67
# true result:  1
# pred result:  1
# Stats AFTER game: [151.1870316858914, 1171.2952290990027], [24.8365886911135, 1713.655816856797]
#
# Result game 84:   ['Juventus', 'Frosinone', -1]
# team1:  Juventus
# team2:  Frosinone
# Stats before game: [199.77095714628396, 977.2296698520162], [176.44577986179834, 1447.7996053477236]
# 	 diff:  23.32517728448562
# true result:  -1
# pred result:  1
# Stats AFTER game: [175.03391748954627, 751.3336347353651], [214.66385250339937, 943.0738629798199]
#
# Result game 85:   ['Fiorentina', 'Lazio', 1]
# team1:  Fiorentina
# team2:  Lazio
# Stats before game: [122.22023302652053, 224.71745647838765], [93.01283950975775, 334.09254112998235]
# 	 diff:  29.207393516762778
# Correct pred:  68
# true result:  1
# pred result:  1
# Stats AFTER game: [124.33154567041426, 208.92789743886652], [90.74738075522355, 303.15539106496317]
#
# Result game 86:   ['Juventus', 'Sampdoria', 1]
# team1:  Juventus
# team2:  Sampdoria
# Stats before game: [175.03391748954627, 751.3336347353651], [61.751037306011526, 338.6367735908977]
# 	 diff:  113.28288018353474
# Correct pred:  69
# true result:  1
# pred result:  1
# Stats AFTER game: [190.25821898167834, 1433.064200405783], [54.828264985710845, 469.7138959488789]
#
# Result game 87:   ['Napoli', 'Empoli', -1]
# team1:  Napoli
# team2:  Empoli
# Stats before game: [71.28379054236997, 302.8954126603443], [155.00880079844796, 719.369049688138]
# 	 diff:  -83.725010256078
# Correct pred:  70
# true result:  -1
# pred result:  -1
# Stats AFTER game: [68.6831068383453, 326.70871558168795], [162.23574640781828, 915.5936855046909]
#
# Result game 88:   ['Udinese', 'Cagliari', -1]
# team1:  Udinese
# team2:  Cagliari
# Stats before game: [23.4017591991252, 927.8801482482502], [220.6345606930966, 1643.152160938599]
# 	 diff:  -197.2328014939714
# Correct pred:  71
# true result:  -1
# pred result:  -1
# Stats AFTER game: [17.237064748874385, 757.1605376883891], [231.50429286632797, 1023.7288965225247]
#
# Result game 89:   ['Frosinone', 'Spal', 1]
# team1:  Frosinone
# team2:  Spal
# Stats before game: [214.66385250339937, 943.0738629798199], [24.8365886911135, 1713.655816856797]
# 	 diff:  189.82726381228588
# Correct pred:  72
# true result:  1
# pred result:  1
# Stats AFTER game: [214.51561709677944, 1098.3086103665935], [25.953803711655745, 2136.9957918460104]
#
# Result game 90:   ['Cagliari', 'Atalanta', -1]
# team1:  Cagliari
# team2:  Atalanta
# Stats before game: [231.50429286632797, 1023.7288965225247], [130.75276547483594, 552.3261377543062]
# 	 diff:  100.75152739149203
# true result:  -1
# pred result:  1
# Stats AFTER game: [151.18424738449903, 452.0874448043771], [172.10783375214626, 382.0374482386961]
#
# Result game 91:   ['Napoli', 'Genoa', -1]
# team1:  Napoli
# team2:  Genoa
# Stats before game: [68.6831068383453, 326.70871558168795], [82.2338931763516, 760.0507631276006]
# 	 diff:  -13.550786338006304
# Correct pred:  73
# true result:  -1
# pred result:  -1
# Stats AFTER game: [63.8532688632598, 285.45040737705466], [94.13220710725852, 564.0725908588292]
#
# Result game 92:   ['Bologna', 'Empoli', 1]
# team1:  Bologna
# team2:  Empoli
# Stats before game: [147.71679484272303, 776.2022700969663], [162.23574640781828, 915.5936855046909]
# 	 diff:  -14.51895156509525
# true result:  1
# pred result:  -1
# Stats AFTER game: [177.42078441096504, 584.3829740157491], [127.40881471963381, 641.1725384618275]
#
# Result game 93:   ['Sampdoria', 'Roma', -1]
# team1:  Sampdoria
# team2:  Roma
# Stats before game: [54.828264985710845, 469.7138959488789], [48.23036465920716, 905.7144929111302]
# 	 diff:  6.597900326503684
# true result:  -1
# pred result:  1
# Stats AFTER game: [36.361351912240046, 367.0460322968541], [83.1389584047758, 538.4566183386651]
#
# Result game 94:   ['Sampdoria', 'Chievo', -1]
# team1:  Sampdoria
# team2:  Chievo
# Stats before game: [36.361351912240046, 367.0460322968541], [151.1870316858914, 1171.2952290990027]
# 	 diff:  -114.82567977365136
# Correct pred:  74
# true result:  -1
# pred result:  -1
# Stats AFTER game: [37.599465492068525, 371.642013482961], [145.74071758530738, 1173.4181299356571]
#
# Result game 95:   ['Spal', 'Atalanta', -1]
# team1:  Spal
# team2:  Atalanta
# Stats before game: [25.953803711655745, 2136.9957918460104], [172.10783375214626, 382.0374482386961]
# 	 diff:  -146.1540300404905
# Correct pred:  75
# true result:  -1
# pred result:  -1
# Stats AFTER game: [50.62236648380624, 3018.6116508213754], [167.67905116728593, 412.14919312771025]
#
# Result game 96:   ['Milan', 'Roma', 1]
# team1:  Milan
# team2:  Roma
# Stats before game: [90.68986274754056, 168.94878322507958], [83.1389584047758, 538.4566183386651]
# 	 diff:  7.550904342764753
# Correct pred:  76
# true result:  1
# pred result:  1
# Stats AFTER game: [98.7229305487921, 173.6743872716537], [58.29630175022759, 561.3715416884288]
#
# Result game 97:   ['Spal', 'Cagliari', -1]
# team1:  Spal
# team2:  Cagliari
# Stats before game: [50.62236648380624, 3018.6116508213754], [151.18424738449903, 452.0874448043771]
# 	 diff:  -100.56188090069278
# Correct pred:  77
# true result:  -1
# pred result:  -1
# Stats AFTER game: [25.435836533517993, 3556.127849966291], [154.47387878958986, 459.6466394097239]
#
# Result game 98:   ['Atalanta', 'Lazio', 1]
# team1:  Atalanta
# team2:  Lazio
# Stats before game: [167.67905116728593, 412.14919312771025], [90.74738075522355, 303.15539106496317]
# 	 diff:  76.93167041206239
# Correct pred:  78
# true result:  1
# pred result:  1
# Stats AFTER game: [171.88723410649504, 501.68750414053164], [87.78506636787509, 369.5369529766697]
#
# Result game 99:   ['Spal', 'Empoli', -1]
# team1:  Spal
# team2:  Empoli
# Stats before game: [25.435836533517993, 3556.127849966291], [127.40881471963381, 641.1725384618275]
# 	 diff:  -101.97297818611582
# Correct pred:  79
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-38.4755604904866, 2018.732574261351], [138.52052811866952, 617.6869046498844]
#
# Result game 100:   ['Genoa', 'Sampdoria', 1]
# team1:  Genoa
# team2:  Sampdoria
# Stats before game: [94.13220710725852, 564.0725908588292], [37.599465492068525, 371.642013482961]
# 	 diff:  56.53274161519
# Correct pred:  80
# true result:  1
# pred result:  1
# Stats AFTER game: [90.28128114294591, 488.73821883772433], [40.111803396168064, 347.03176620136315]
#
# Result game 101:   ['Juventus', 'Genoa', -1]
# team1:  Juventus
# team2:  Genoa
# Stats before game: [190.25821898167834, 1433.064200405783], [90.28128114294591, 488.73821883772433]
# 	 diff:  99.97693783873243
# true result:  -1
# pred result:  1
# Stats AFTER game: [99.49061134548332, 580.8924118372568], [121.54779067084854, 387.3261138973613]
#
# Result game 102:   ['Roma', 'Inter', -1]
# team1:  Roma
# team2:  Inter
# Stats before game: [58.29630175022759, 561.3715416884288], [101.15586311830323, 381.4866874862922]
# 	 diff:  -42.85956136807564
# Correct pred:  81
# true result:  -1
# pred result:  -1
# Stats AFTER game: [53.83794209129784, 893.471718805656], [103.64721688900026, 534.0122669149569]
#
# Result game 103:   ['Sassuolo', 'Milan', -1]
# team1:  Sassuolo
# team2:  Milan
# Stats before game: [68.35594007435665, 531.6413515115951], [98.7229305487921, 173.6743872716537]
# 	 diff:  -30.366990474435454
# Correct pred:  82
# true result:  -1
# pred result:  -1
# Stats AFTER game: [57.2092535814583, 441.34813427376423], [102.21285563521877, 160.20949111071042]
#
# Result game 104:   ['Cagliari', 'Fiorentina', 1]
# team1:  Cagliari
# team2:  Fiorentina
# Stats before game: [154.47387878958986, 459.6466394097239], [124.33154567041426, 208.92789743886652]
# 	 diff:  30.142333119175603
# Correct pred:  83
# true result:  1
# pred result:  1
# Stats AFTER game: [168.60964177100303, 424.85183618118043], [118.10522439589263, 204.6290105932137]
#
# Result game 105:   ['Sassuolo', 'Lazio', -1]
# team1:  Sassuolo
# team2:  Lazio
# Stats before game: [57.2092535814583, 441.34813427376423], [87.78506636787509, 369.5369529766697]
# 	 diff:  -30.57581278641679
# Correct pred:  84
# true result:  -1
# pred result:  -1
# Stats AFTER game: [45.56182813476099, 451.5850771725253], [97.729403232709, 383.58654337122164]
#
# Result game 106:   ['Inter', 'Spal', 1]
# team1:  Inter
# team2:  Spal
# Stats before game: [103.64721688900026, 534.0122669149569], [-38.4755604904866, 2018.732574261351]
# 	 diff:  142.12277737948688
# Correct pred:  85
# true result:  1
# pred result:  1
# Stats AFTER game: [102.51058134483267, 458.7214172981188], [-32.17313280641514, 985.1038452926662]
#
# Result game 107:   ['Parma', 'Sassuolo', 1]
# team1:  Parma
# team2:  Sassuolo
# Stats before game: [58.320015551525415, 261.10541182630766], [45.56182813476099, 451.5850771725253]
# 	 diff:  12.758187416764429
# Correct pred:  86
# true result:  1
# pred result:  1
# Stats AFTER game: [66.97303877792783, 232.7485325658968], [31.028535633761734, 379.0673643090771]
#
# Result game 108:   ['Spal', 'Genoa', -1]
# team1:  Spal
# team2:  Genoa
# Stats before game: [-32.17313280641514, 985.1038452926662], [121.54779067084854, 387.3261138973613]
# 	 diff:  -153.72092347726368
# Correct pred:  87
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-51.9368905316135, 1156.1590488531856], [129.9749876779928, 416.1289942918486]
#
# Result game 109:   ['Chievo', 'Milan', 1]
# team1:  Chievo
# team2:  Milan
# Stats before game: [145.74071758530738, 1173.4181299356571], [102.21285563521877, 160.20949111071042]
# 	 diff:  43.52786195008861
# Correct pred:  88
# true result:  1
# pred result:  1
# Stats AFTER game: [151.3721215277482, 868.1864583006594], [101.45047166308487, 152.49676958607625]
#
# Result game 110:   ['Frosinone', 'Udinese', 1]
# team1:  Frosinone
# team2:  Udinese
# Stats before game: [214.51561709677944, 1098.3086103665935], [17.237064748874385, 757.1605376883891]
# 	 diff:  197.27855234790505
# Correct pred:  89
# true result:  1
# pred result:  1
# Stats AFTER game: [229.59300662440336, 2084.084196824893], [7.474172572981953, 1249.3630163184068]
#
# Result game 111:   ['Sassuolo', 'Cagliari', -1]
# team1:  Sassuolo
# team2:  Cagliari
# Stats before game: [31.028535633761734, 379.0673643090771], [168.60964177100303, 424.85183618118043]
# 	 diff:  -137.5811061372413
# Correct pred:  90
# true result:  -1
# pred result:  -1
# Stats AFTER game: [47.39195140352317, 478.43767428720787], [150.13368995419287, 574.9807239309675]
#
# Result game 112:   ['Parma', 'Udinese', 1]
# team1:  Parma
# team2:  Udinese
# Stats before game: [66.97303877792783, 232.7485325658968], [7.474172572981953, 1249.3630163184068]
# 	 diff:  59.49886620494587
# Correct pred:  91
# true result:  1
# pred result:  1
# Stats AFTER game: [71.95292349348223, 236.19809355343807], [-18.78706856651339, 1400.5555598798937]
#
# Result game 113:   ['Genoa', 'Juventus', 1]
# team1:  Genoa
# team2:  Juventus
# Stats before game: [129.9749876779928, 416.1289942918486], [99.49061134548332, 580.8924118372568]
# 	 diff:  30.484376332509484
# Correct pred:  92
# true result:  1
# pred result:  1
# Stats AFTER game: [135.6768103864743, 391.8207572575485], [91.4241353788034, 521.8147185146789]
#
# Result game 114:   ['Roma', 'Chievo', -1]
# team1:  Roma
# team2:  Chievo
# Stats before game: [53.83794209129784, 893.471718805656], [151.3721215277482, 868.1864583006594]
# 	 diff:  -97.53417943645036
# Correct pred:  93
# true result:  -1
# pred result:  -1
# Stats AFTER game: [65.88855882012574, 904.8971534255478], [139.24529249131487, 887.1473684488647]
#
# Result game 115:   ['Juventus', 'Roma', 1]
# team1:  Juventus
# team2:  Roma
# Stats before game: [91.4241353788034, 521.8147185146789], [65.88855882012574, 904.8971534255478]
# 	 diff:  25.53557655867766
# Correct pred:  94
# true result:  1
# pred result:  1
# Stats AFTER game: [105.1692733394508, 512.5995526472353], [41.50906453585808, 800.0785672916472]
#
# Result game 116:   ['Torino', 'Udinese', 1]
# team1:  Torino
# team2:  Udinese
# Stats before game: [24.309124626536203, 2424.486953079016], [-18.78706856651339, 1400.5555598798937]
# 	 diff:  43.096193193049594
# Correct pred:  95
# true result:  1
# pred result:  1
# Stats AFTER game: [28.884019211064246, 1583.1912473359662], [-21.821744306466936, 1144.6246679875824]
#
# Result game 117:   ['Juventus', 'Spal', 1]
# team1:  Juventus
# team2:  Spal
# Stats before game: [105.1692733394508, 512.5995526472353], [-51.9368905316135, 1156.1590488531856]
# 	 diff:  157.1061638710643
# Correct pred:  96
# true result:  1
# pred result:  1
# Stats AFTER game: [107.17956742260046, 606.5366266027207], [-56.9724448148543, 1658.0724844210204]
#
# Result game 118:   ['Parma', 'Inter', -1]
# team1:  Parma
# team2:  Inter
# Stats before game: [71.95292349348223, 236.19809355343807], [102.51058134483267, 458.7214172981188]
# 	 diff:  -30.55765785135044
# Correct pred:  97
# true result:  -1
# pred result:  -1
# Stats AFTER game: [63.032857769783895, 235.0664327199129], [119.42951837379948, 453.77654200235196]
#
# Result game 119:   ['Lazio', 'Napoli', 1]
# team1:  Lazio
# team2:  Napoli
# Stats before game: [97.729403232709, 383.58654337122164], [63.8532688632598, 285.45040737705466]
# 	 diff:  33.876134369449204
# Correct pred:  98
# true result:  1
# pred result:  1
# Stats AFTER game: [104.63561133904997, 342.93594943089715], [59.007039390942225, 252.5764999115074]
#
# Result game 120:   ['Bologna', 'Fiorentina', 1]
# team1:  Bologna
# team2:  Fiorentina
# Stats before game: [177.42078441096504, 584.3829740157491], [118.10522439589263, 204.6290105932137]
# 	 diff:  59.31556001507241
# Correct pred:  99
# true result:  1
# pred result:  1
# Stats AFTER game: [189.86963440006406, 590.4725108974311], [113.84089458868571, 199.96664627868148]
#
# Result game 121:   ['Roma', 'Sassuolo', 1]
# team1:  Roma
# team2:  Sassuolo
# Stats before game: [41.50906453585808, 800.0785672916472], [47.39195140352317, 478.43767428720787]
# 	 diff:  -5.882886867665093
# true result:  1
# pred result:  -1
# Stats AFTER game: [67.22150357739906, 494.68704611708483], [32.18207279966136, 371.9901138358892]
#
# Result game 122:   ['Roma', 'Bologna', -1]
# team1:  Roma
# team2:  Bologna
# Stats before game: [67.22150357739906, 494.68704611708483], [189.86963440006406, 590.4725108974311]
# 	 diff:  -122.648130822665
# Correct pred:  100
# true result:  -1
# pred result:  -1
# Stats AFTER game: [69.74803125598037, 534.1474895220725], [186.66888951824205, 647.7043949818099]
#
# Result game 123:   ['Chievo', 'Napoli', 1]
# team1:  Chievo
# team2:  Napoli
# Stats before game: [139.24529249131487, 887.1473684488647], [59.007039390942225, 252.5764999115074]
# 	 diff:  80.23825310037265
# Correct pred:  101
# true result:  1
# pred result:  1
# Stats AFTER game: [153.39030286644615, 1848.0440437856391], [55.017523500457976, 321.1341800091481]
#
# Result game 124:   ['Bologna', 'Lazio', 1]
# team1:  Bologna
# team2:  Lazio
# Stats before game: [186.66888951824205, 647.7043949818099], [104.63561133904997, 342.93594943089715]
# 	 diff:  82.03327817919208
# Correct pred:  102
# true result:  1
# pred result:  1
# Stats AFTER game: [176.71124190378683, 693.1374906912297], [109.52432837849523, 369.7620814222995]
#
# Result game 125:   ['Cagliari', 'Udinese', 1]
# team1:  Cagliari
# team2:  Udinese
# Stats before game: [150.13368995419287, 574.9807239309675], [-21.821744306466936, 1144.6246679875824]
# 	 diff:  171.9554342606598
# Correct pred:  103
# true result:  1
# pred result:  1
# Stats AFTER game: [148.25452764995862, 730.850803054735], [-18.754032650536598, 1757.2166355295587]
#
# Result game 126:   ['Napoli', 'Sassuolo', 1]
# team1:  Napoli
# team2:  Sassuolo
# Stats before game: [55.017523500457976, 321.1341800091481], [32.18207279966136, 371.9901138358892]
# 	 diff:  22.835450700796613
# Correct pred:  104
# true result:  1
# pred result:  1
# Stats AFTER game: [66.31211093962565, 300.2677157701035], [19.272609846300657, 351.3737036370956]
#
# Result game 127:   ['Cagliari', 'Sassuolo', 1]
# team1:  Cagliari
# team2:  Sassuolo
# Stats before game: [148.25452764995862, 730.850803054735], [19.272609846300657, 351.3737036370956]
# 	 diff:  128.98191780365795
# Correct pred:  105
# true result:  1
# pred result:  1
# Stats AFTER game: [143.14703816554777, 880.0744321618827], [21.75699450811744, 375.252255134161]
#
# Result game 128:   ['Genoa', 'Torino', 1]
# team1:  Genoa
# team2:  Torino
# Stats before game: [135.6768103864743, 391.8207572575485], [28.884019211064246, 1583.1912473359662]
# 	 diff:  106.79279117541006
# Correct pred:  106
# true result:  1
# pred result:  1
# Stats AFTER game: [145.59817552968306, 484.35966847462345], [-11.0943561305256, 3027.9371098958286]
#
# Result game 129:   ['Genoa', 'Lazio', 1]
# team1:  Genoa
# team2:  Lazio
# Stats before game: [145.59817552968306, 484.35966847462345], [109.52432837849523, 369.7620814222995]
# 	 diff:  36.073847151187834
# Correct pred:  107
# true result:  1
# pred result:  1
# Stats AFTER game: [147.440208802289, 487.4876763426615], [108.11582874516803, 377.7407486859305]
#
# Result game 130:   ['Sampdoria', 'Frosinone', -1]
# team1:  Sampdoria
# team2:  Frosinone
# Stats before game: [40.111803396168064, 347.03176620136315], [229.59300662440336, 2084.084196824893]
# 	 diff:  -189.4812032282353
# Correct pred:  108
# true result:  -1
# pred result:  -1
# Stats AFTER game: [32.03950588898535, 308.1157921994153], [278.37370609673775, 1049.2742087368006]
#
# Result game 131:   ['Roma', 'Fiorentina', -1]
# team1:  Roma
# team2:  Fiorentina
# Stats before game: [69.74803125598037, 534.1474895220725], [113.84089458868571, 199.96664627868148]
# 	 diff:  -44.09286333270535
# Correct pred:  109
# true result:  -1
# pred result:  -1
# Stats AFTER game: [62.12655598680729, 789.4112718729984], [116.73103396866686, 253.0442034700154]
#
# Result game 132:   ['Cagliari', 'Sampdoria', 1]
# team1:  Cagliari
# team2:  Sampdoria
# Stats before game: [143.14703816554777, 880.0744321618827], [32.03950588898535, 308.1157921994153]
# 	 diff:  111.10753227656241
# Correct pred:  110
# true result:  1
# pred result:  1
# Stats AFTER game: [152.7182897733475, 1191.5772279085536], [28.86020644323362, 342.27540456787403]
#
# Result game 133:   ['Sampdoria', 'Spal', 1]
# team1:  Sampdoria
# team2:  Spal
# Stats before game: [28.86020644323362, 342.27540456787403], [-56.9724448148543, 1658.0724844210204]
# 	 diff:  85.83265125808792
# Correct pred:  111
# true result:  1
# pred result:  1
# Stats AFTER game: [28.558379487437836, 327.5743789390712], [-55.93500059426994, 1373.6002570588305]
#
# Result game 134:   ['Sassuolo', 'Atalanta', -1]
# team1:  Sassuolo
# team2:  Atalanta
# Stats before game: [21.75699450811744, 375.252255134161], [171.88723410649504, 501.68750414053164]
# 	 diff:  -150.1302395983776
# Correct pred:  112
# true result:  -1
# pred result:  -1
# Stats AFTER game: [20.547393233780614, 402.11386766258124], [173.81501410540326, 557.2567664529248]
#
# Result game 135:   ['Torino', 'Chievo', -1]
# team1:  Torino
# team2:  Chievo
# Stats before game: [-11.0943561305256, 3027.9371098958286], [153.39030286644615, 1848.0440437856391]
# 	 diff:  -164.48465899697175
# Correct pred:  113
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-82.76863475955862, 2096.9794833752767], [197.11125116335293, 1519.7533630743021]
#
# Result game 136:   ['Sampdoria', 'Genoa', -1]
# team1:  Sampdoria
# team2:  Genoa
# Stats before game: [28.558379487437836, 327.5743789390712], [147.440208802289, 487.4876763426615]
# 	 diff:  -118.88182931485116
# Correct pred:  114
# true result:  -1
# pred result:  -1
# Stats AFTER game: [29.786751001460253, 367.32655096206594], [145.38835479210448, 585.9383686072791]
#
# Result game 137:   ['Udinese', 'Bologna', -1]
# team1:  Udinese
# team2:  Bologna
# Stats before game: [-18.754032650536598, 1757.2166355295587], [176.71124190378683, 693.1374906912297]
# 	 diff:  -195.46527455432343
# Correct pred:  115
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-33.04099584763086, 1589.5218743366809], [181.67251526238985, 674.9834144550285]
#
# Result game 138:   ['Atalanta', 'Inter', 1]
# team1:  Atalanta
# team2:  Inter
# ...
# 	 diff:  125.99161521285323
# Correct pred:  296
# true result:  1
# pred result:  1
# Stats AFTER game: [211.99490711226946, 2301.653007079425], [75.99358394305045, 489.3802629118637]
#
# Result game 336:   ['Juventus', 'Torino', 1]
# team1:  Juventus
# team2:  Torino
# Stats before game: [93.69657738056573, 500.9306231117284], [-67.66756124623795, 1116.9612706152554]
# 	 diff:  161.36413862680368
# Correct pred:  297
# true result:  1
# pred result:  1
# Stats AFTER game: [99.95910695363337, 878.8981711169603], [-82.33972661860791, 2988.8438673057994]
#
# Result game 337:   ['Napoli', 'Atalanta', -1]
# team1:  Napoli
# team2:  Atalanta
# Stats before game: [33.768836580791294, 2491.9264360940647], [280.6322378172914, 3505.628909650806]
# 	 diff:  -246.86340123650012
# Correct pred:  298
# true result:  -1
# pred result:  -1
# Stats AFTER game: [39.82907539653341, 1762.61511736501], [270.95706148469765, 2116.586183901872]
#
# Result game 338:   ['Udinese', 'Chievo', -1]
# team1:  Udinese
# team2:  Chievo
# Stats before game: [-82.23386507253532, 1866.7518953748522], [222.95316238421026, 1278.3020040545955]
# 	 diff:  -305.18702745674557
# Correct pred:  299
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-97.16501822060172, 1936.373857481644], [233.94848632142472, 1278.3512255492826]
#
# Result game 339:   ['Milan', 'Genoa', -1]
# team1:  Milan
# team2:  Genoa
# Stats before game: [87.60625833248575, 219.43581818430556], [157.67334285729112, 319.99832546142244]
# 	 diff:  -70.06708452480537
# Correct pred:  300
# true result:  -1
# pred result:  -1
# Stats AFTER game: [85.52899517213137, 270.42156801745693], [160.97573725638165, 427.06584728613996]
#
# Result game 340:   ['Frosinone', 'Napoli', 1]
# team1:  Frosinone
# team2:  Napoli
# Stats before game: [136.10323640191626, 509.1701984791679], [39.82907539653341, 1762.61511736501]
# 	 diff:  96.27416100538285
# Correct pred:  301
# true result:  1
# pred result:  1
# Stats AFTER game: [129.66816344187023, 457.406755078816], [60.48005473017777, 1165.797833344415]
#
# Result game 341:   ['Atalanta', 'Fiorentina', 1]
# team1:  Atalanta
# team2:  Fiorentina
# Stats before game: [270.95706148469765, 2116.586183901872], [150.91600809690263, 560.9483536438585]
# 	 diff:  120.04105338779502
# Correct pred:  302
# true result:  1
# pred result:  1
# Stats AFTER game: [289.28921675485486, 4026.859551678817], [145.60621519240888, 701.8845509815301]
#
# Result game 342:   ['Cagliari', 'Juventus', 1]
# team1:  Cagliari
# team2:  Juventus
# Stats before game: [211.99490711226946, 2301.653007079425], [99.95910695363337, 878.8981711169603]
# 	 diff:  112.03580015863609
# Correct pred:  303
# true result:  1
# pred result:  1
# Stats AFTER game: [222.30490263175892, 2460.1340272504062], [96.37539789617419, 925.8851907486525]
#
# Result game 343:   ['Empoli', 'Roma', 1]
# team1:  Empoli
# team2:  Roma
# Stats before game: [143.3350348326334, 1178.7815559213434], [75.99358394305045, 489.3802629118637]
# 	 diff:  67.34145088958294
# Correct pred:  304
# true result:  1
# pred result:  1
# Stats AFTER game: [164.87064710815037, 1526.4536505074961], [67.62240986671044, 554.4106182996662]
#
# Result game 344:   ['Milan', 'Empoli', -1]
# team1:  Milan
# team2:  Empoli
# Stats before game: [85.52899517213137, 270.42156801745693], [164.87064710815037, 1526.4536505074961]
# 	 diff:  -79.34165193601899
# Correct pred:  305
# true result:  -1
# pred result:  -1
# Stats AFTER game: [85.99565494133043, 259.3325407732811], [161.3319098494275, 858.9408196404597]
#
# Result game 345:   ['Chievo', 'Lazio', 1]
# team1:  Chievo
# team2:  Lazio
# Stats before game: [233.94848632142472, 1278.3512255492826], [99.89431346824666, 226.22833351805826]
# 	 diff:  134.05417285317804
# Correct pred:  306
# true result:  1
# pred result:  1
# Stats AFTER game: [272.0991012568875, 1682.6370950420683], [93.10151786154225, 243.5159686432615]
#
# Result game 346:   ['Empoli', 'Torino', 1]
# team1:  Empoli
# team2:  Torino
# Stats before game: [161.3319098494275, 858.9408196404597], [-82.33972661860791, 2988.8438673057994]
# 	 diff:  243.6716364680354
# Correct pred:  307
# true result:  1
# pred result:  1
# Stats AFTER game: [162.91972803465472, 795.797905575429], [-89.08204361915773, 1862.2043099602288]
#
# Result game 347:   ['Torino', 'Atalanta', -1]
# team1:  Torino
# team2:  Atalanta
# Stats before game: [-89.08204361915773, 1862.2043099602288], [289.28921675485486, 4026.859551678817]
# 	 diff:  -378.3712603740126
# Correct pred:  308
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-87.17380967881383, 1432.4445972269812], [284.301081849385, 2166.831671160272]
#
# Result game 348:   ['Sampdoria', 'Napoli', -1]
# team1:  Sampdoria
# team2:  Napoli
# Stats before game: [-13.856639078946316, 1129.760730161649], [60.48005473017777, 1165.797833344415]
# 	 diff:  -74.33669380912409
# Correct pred:  309
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-31.214992869066286, 1078.905128625799], [78.84637573884915, 1109.0367369562457]
#
# Result game 349:   ['Parma', 'Fiorentina', -1]
# team1:  Parma
# team2:  Fiorentina
# Stats before game: [31.048134110179568, 2219.230434671677], [145.60621519240888, 701.8845509815301]
# 	 diff:  -114.55808108222931
# Correct pred:  310
# true result:  -1
# pred result:  -1
# Stats AFTER game: [29.43925911592521, 1825.4137918473673], [146.11114627075912, 654.8173242664999]
#
# Result game 350:   ['Sampdoria', 'Lazio', -1]
# team1:  Sampdoria
# team2:  Lazio
# Stats before game: [-31.214992869066286, 1078.905128625799], [93.10151786154225, 243.5159686432615]
# 	 diff:  -124.31651073060854
# Correct pred:  311
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-62.707506125278265, 1158.9902968580834], [100.17481544247188, 241.50464288871083]
#
# Result game 351:   ['Cagliari', 'Lazio', 1]
# team1:  Cagliari
# team2:  Lazio
# Stats before game: [222.30490263175892, 2460.1340272504062], [100.17481544247188, 241.50464288871083]
# 	 diff:  122.13008718928704
# Correct pred:  312
# true result:  1
# pred result:  1
# Stats AFTER game: [270.98259044360697, 2357.2311654489154], [95.10712553593065, 238.24153689320036]
#
# Result game 352:   ['Torino', 'Empoli', -1]
# team1:  Torino
# team2:  Empoli
# Stats before game: [-87.17380967881383, 1432.4445972269812], [162.91972803465472, 795.797905575429]
# 	 diff:  -250.09353771346855
# Correct pred:  313
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-120.97219240986537, 1032.71362956355], [181.74466663353815, 675.6937546671058]
#
# Result game 353:   ['Genoa', 'Empoli', -1]
# team1:  Genoa
# team2:  Empoli
# Stats before game: [160.97573725638165, 427.06584728613996], [181.74466663353815, 675.6937546671058]
# 	 diff:  -20.768929377156496
# Correct pred:  314
# true result:  -1
# pred result:  -1
# Stats AFTER game: [154.39672935806422, 395.75165581672815], [190.60270328927436, 547.9526274010437]
#
# Result game 354:   ['Frosinone', 'Lazio', 1]
# team1:  Frosinone
# team2:  Lazio
# Stats before game: [129.66816344187023, 457.406755078816], [95.10712553593065, 238.24153689320036]
# 	 diff:  34.561037905939585
# Correct pred:  315
# true result:  1
# pred result:  1
# Stats AFTER game: [135.5829666182294, 464.76323870495236], [92.11045239404068, 234.32570479295242]
#
# Result game 355:   ['Empoli', 'Spal', 1]
# team1:  Empoli
# team2:  Spal
# Stats before game: [190.60270328927436, 547.9526274010437], [-92.42889482058231, 727.4420956467899]
# 	 diff:  283.03159810985665
# Correct pred:  316
# true result:  1
# pred result:  1
# Stats AFTER game: [187.58958058450585, 641.639358753691], [-88.34781607857923, 873.9808341891664]
#
# Result game 356:   ['Milan', 'Lazio', -1]
# team1:  Milan
# team2:  Lazio
# Stats before game: [85.99565494133043, 259.3325407732811], [92.11045239404068, 234.32570479295242]
# 	 diff:  -6.114797452710249
# Correct pred:  317
# true result:  -1
# pred result:  -1
# Stats AFTER game: [77.87803842360526, 175.68838077160413], [98.692559700563, 162.45026417047512]
#
# Result game 357:   ['Udinese', 'Atalanta', -1]
# team1:  Udinese
# team2:  Atalanta
# Stats before game: [-97.16501822060172, 1936.373857481644], [284.301081849385, 2166.831671160272]
# 	 diff:  -381.46610006998674
# Correct pred:  318
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-109.65158054981389, 2559.0787721759707], [298.87496109266345, 3072.259359634062]
#
# Result game 358:   ['Juventus', 'Fiorentina', -1]
# team1:  Juventus
# team2:  Fiorentina
# Stats before game: [96.37539789617419, 925.8851907486525], [146.11114627075912, 654.8173242664999]
# 	 diff:  -49.73574837458493
# Correct pred:  319
# true result:  -1
# pred result:  -1
# Stats AFTER game: [84.6551717551799, 748.3504512512606], [153.8818569757917, 542.026301156737]
#
# Result game 359:   ['Frosinone', 'Bologna', -1]
# team1:  Frosinone
# team2:  Bologna
# Stats before game: [135.5829666182294, 464.76323870495236], [331.7727665160777, 2316.685647930331]
# 	 diff:  -196.1897998978483
# Correct pred:  320
# true result:  -1
# pred result:  -1
# Stats AFTER game: [122.31485937847552, 462.76990688893], [397.3871852585792, 1921.9626893982515]
#
# Result game 360:   ['Chievo', 'Sampdoria', 1]
# team1:  Chievo
# team2:  Sampdoria
# Stats before game: [272.0991012568875, 1682.6370950420683], [-62.707506125278265, 1158.9902968580834]
# 	 diff:  334.80660738216574
# Correct pred:  321
# true result:  1
# pred result:  1
# Stats AFTER game: [224.2047400162597, 1721.0136646222004], [-28.652373006579932, 1173.197377375119]
#
# Result game 361:   ['Juventus', 'Udinese', 1]
# team1:  Juventus
# team2:  Udinese
# Stats before game: [84.6551717551799, 748.3504512512606], [-109.65158054981389, 2559.0787721759707]
# 	 diff:  194.30675230499378
# Correct pred:  322
# true result:  1
# pred result:  1
# Stats AFTER game: [106.16023057720602, 681.3871598586454], [-183.97021945816343, 1906.5889388457335]
#
# Result game 362:   ['Bologna', 'Atalanta', -1]
# team1:  Bologna
# team2:  Atalanta
# Stats before game: [397.3871852585792, 1921.9626893982515], [298.87496109266345, 3072.259359634062]
# 	 diff:  98.51222416591577
# true result:  -1
# pred result:  1
# Stats AFTER game: [341.4780404715636, 1366.7535953728], [389.18937970611455, 1603.174393449909]
#
# Result game 363:   ['Atalanta', 'Juventus', 1]
# team1:  Atalanta
# team2:  Juventus
# Stats before game: [389.18937970611455, 1603.174393449909], [106.16023057720602, 681.3871598586454]
# 	 diff:  283.02914912890856
# Correct pred:  323
# true result:  1
# pred result:  1
# Stats AFTER game: [371.6705433501237, 1318.703122341341], [113.56562103993512, 663.0756312848208]
#
# Result game 364:   ['Sassuolo', 'Frosinone', -1]
# team1:  Sassuolo
# team2:  Frosinone
# Stats before game: [12.965304554824469, 2366.2668010081184], [122.31485937847552, 462.76990688893]
# 	 diff:  -109.34955482365105
# Correct pred:  324
# true result:  -1
# pred result:  -1
# Stats AFTER game: [40.63528819965683, 2046.072482712693], [116.671184772999, 441.93839852804666]
#
# Result game 365:   ['Chievo', 'Frosinone', 1]
# team1:  Chievo
# team2:  Frosinone
# Stats before game: [224.2047400162597, 1721.0136646222004], [116.671184772999, 441.93839852804666]
# 	 diff:  107.53355524326071
# Correct pred:  325
# true result:  1
# pred result:  1
# Stats AFTER game: [262.3384948468904, 2835.739962525817], [107.01805030836374, 526.5765469365408]
#
# Result game 366:   ['Spal', 'Juventus', -1]
# team1:  Spal
# team2:  Juventus
# Stats before game: [-88.34781607857923, 873.9808341891664], [113.56562103993512, 663.0756312848208]
# 	 diff:  -201.91343711851437
# Correct pred:  326
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-90.30699536994733, 1444.8700876929836], [114.4325261239082, 981.5676684791767]
#
# Result game 367:   ['Napoli', 'Inter', -1]
# team1:  Napoli
# team2:  Inter
# Stats before game: [78.84637573884915, 1109.0367369562457], [120.30738895038888, 463.38194539184144]
# 	 diff:  -41.461013211539736
# Correct pred:  327
# true result:  -1
# pred result:  -1
# Stats AFTER game: [69.54382814694866, 978.6953523099897], [123.29649061582502, 424.6663268156995]
#
# Result game 368:   ['Juventus', 'Inter', -1]
# team1:  Juventus
# team2:  Inter
# Stats before game: [114.4325261239082, 981.5676684791767], [123.29649061582502, 424.6663268156995]
# 	 diff:  -8.863964491916818
# Correct pred:  328
# true result:  -1
# pred result:  -1
# Stats AFTER game: [94.67719122870918, 672.4114051478156], [131.1641228914198, 362.901120070964]
#
# Result game 369:   ['Juventus', 'Sassuolo', 1]
# team1:  Juventus
# team2:  Sassuolo
# Stats before game: [94.67719122870918, 672.4114051478156], [40.63528819965683, 2046.072482712693]
# 	 diff:  54.04190302905235
# Correct pred:  329
# true result:  1
# pred result:  1
# Stats AFTER game: [114.50841335277956, 690.6797939547057], [-21.39974804068429, 2208.141498560585]
#
# Result game 370:   ['Atalanta', 'Empoli', 1]
# team1:  Atalanta
# team2:  Empoli
# Stats before game: [371.6705433501237, 1318.703122341341], [187.58958058450585, 641.639358753691]
# 	 diff:  184.08096276561784
# Correct pred:  330
# true result:  1
# pred result:  1
# Stats AFTER game: [358.35215056285364, 2637.123931095306], [194.83658392771613, 942.5500749302583]
#
# Result game 371:   ['Frosinone', 'Empoli', -1]
# team1:  Frosinone
# team2:  Empoli
# Stats before game: [107.01805030836374, 526.5765469365408], [194.83658392771613, 942.5500749302583]
# 	 diff:  -87.8185336193524
# Correct pred:  331
# true result:  -1
# pred result:  -1
# Stats AFTER game: [100.52168378509046, 585.8098168776438], [206.8769495795071, 1089.6107267092566]
#
# Result game 372:   ['Milan', 'Juventus', -1]
# team1:  Milan
# team2:  Juventus
# Stats before game: [77.87803842360526, 175.68838077160413], [114.50841335277956, 690.6797939547057]
# 	 diff:  -36.630374929174295
# Correct pred:  332
# true result:  -1
# pred result:  -1
# Stats AFTER game: [73.86462533437066, 180.50716912576019], [130.12625739040485, 706.5068690855744]
#
# Result game 373:   ['Spal', 'Napoli', -1]
# team1:  Spal
# team2:  Napoli
# Stats before game: [-90.30699536994733, 1444.8700876929836], [69.54382814694866, 978.6953523099897]
# 	 diff:  -159.85082351689599
# Correct pred:  333
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-65.2432350787727, 1611.8441484241173], [52.37168162171046, 1031.10470991515]
#
# Result game 374:   ['Milan', 'Torino', 1]
# team1:  Milan
# team2:  Torino
# Stats before game: [73.86462533437066, 180.50716912576019], [-120.97219240986537, 1032.71362956355]
# 	 diff:  194.83681774423604
# Correct pred:  334
# true result:  1
# pred result:  1
# Stats AFTER game: [75.29652254330121, 191.80452563217807], [-130.26781341817488, 1706.4732009423597]
#
# Result game 375:   ['Cagliari', 'Inter', 1]
# team1:  Cagliari
# team2:  Inter
# Stats before game: [270.98259044360697, 2357.2311654489154], [131.1641228914198, 362.901120070964]
# 	 diff:  139.81846755218717
# Correct pred:  335
# true result:  1
# pred result:  1
# Stats AFTER game: [256.5504994604685, 3824.0521729002185], [133.20447676292522, 412.0370662326218]
#
# Result game 376:   ['Empoli', 'Frosinone', 1]
# team1:  Empoli
# team2:  Frosinone
# Stats before game: [206.8769495795071, 1089.6107267092566], [100.52168378509046, 585.8098168776438]
# 	 diff:  106.35526579441665
# Correct pred:  336
# true result:  1
# pred result:  1
# Stats AFTER game: [195.71795037640305, 1214.9978102373534], [106.30013381354591, 624.0510987138362]
#
# Result game 377:   ['Udinese', 'Lazio', -1]
# team1:  Udinese
# team2:  Lazio
# Stats before game: [-183.97021945816343, 1906.5889388457335], [98.692559700563, 162.45026417047512]
# 	 diff:  -282.66277915872644
# Correct pred:  337
# true result:  -1
# pred result:  -1
# Stats AFTER game: [-186.7378617942173, 1690.180697045156], [98.8213757247917, 159.50233332867208]
#
# Result game 378:   ['Napoli', 'Chievo', -1]
# team1:  Napoli
# team2:  Chievo
# Stats before game: [52.37168162171046, 1031.10470991515], [262.3384948468904, 2835.739962525817]
# 	 diff:  -209.96681322517995
# Correct pred:  338
# true result:  -1
# pred result:  -1
# Stats AFTER game: [88.71989197487105, 941.171887447966], [163.0816779632476, 2309.6339693771124]
#
# Result game 379:   ['Sampdoria', 'Sassuolo', 1]
# team1:  Sampdoria
# team2:  Sassuolo
# Stats before game: [-28.652373006579932, 1173.197377375119], [-21.39974804068429, 2208.141498560585]
# 	 diff:  -7.252624965895642
# true result:  1
# pred result:  -1
# Stats AFTER game: [-6.483511259814612, 903.1317286679127], [-61.96853113810226, 1318.8060452351638]
#
# correct_predictions  338
# reslist:  380
# draws:  0
# performance:  0.8894736842105263

# %%
ranking(stats_dictionary
       )
# andra körning.
# Out:
# List of teams ranked by mean skill in descending order:
#
# Atalanta [358.35215056285364, 2637.123931095306]
# Bologna [341.4780404715636, 1366.7535953728]
# Cagliari [256.5504994604685, 3824.0521729002185]
# Empoli [195.71795037640305, 1214.9978102373534]
# Chievo [163.0816779632476, 2309.6339693771124]
# Genoa [154.39672935806422, 395.75165581672815]
# Fiorentina [153.8818569757917, 542.026301156737]
# Inter [133.20447676292522, 412.0370662326218]
# Juventus [130.12625739040485, 706.5068690855744]
# Frosinone [106.30013381354591, 624.0510987138362]
# Lazio [98.8213757247917, 159.50233332867208]
# Napoli [88.71989197487105, 941.171887447966]
# Milan [75.29652254330121, 191.80452563217807]
# Roma [67.62240986671044, 554.4106182996662]
# Parma [29.43925911592521, 1825.4137918473673]
# Sampdoria [-6.483511259814612, 903.1317286679127]
# Sassuolo [-61.96853113810226, 1318.8060452351638]
# Spal [-65.2432350787727, 1611.8441484241173]
# Torino [-130.26781341817488, 1706.4732009423597]
# Udinese [-186.7378617942173, 1690.180697045156]
